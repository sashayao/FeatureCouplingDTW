# %%
#imports
import pandas as pd     
import matplotlib.pyplot as plt    
# %matplotlib inline
import seaborn as sns    
import numpy as np
from sklearn.mixture import GaussianMixture as GMM
import os
sns.set(style="darkgrid")
from math import pi
from glob import glob
import re
import math
import scipy.interpolate as interp
from tslearn.metrics import dtw, dtw_path
from dtw import dtw,accelerated_dtw
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tslearn/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %% [markdown]
# #### Get Data

# %%
# Reference: https://perials.com/getting-csv-files-directory-subdirectories-using-python/
def getData(PATH, name):
#     PATH = "happinessData/"

    EXT = "*.csv"
    files = [file for path, subdir, files in os.walk(PATH)
                for file in glob(os.path.join(path, EXT))]
    l = []
    for f in files:
        df = pd.read_csv(f)
        result = re.search('/(.*).csv', f)
#         r = re.search('/(.*)',str(result.group(1)))
        video = result.group(1)
        df['video'] = np.full(len(df), video, dtype = int)
        l.append(df)
    df = pd.concat(l, ignore_index=True)
    df['name'] = name
    df = df.rename(columns=lambda x: x.strip())
    return df

# %% [markdown]
# #### Processing Data

# %%
def processData(df):
    df = df[df['success'] != 0]
    df = df[df['confidence'] > 0.80]
    # extracting features
    au = [ 'timestamp','face_id','video', 'gaze_angle_x', 'gaze_angle_y', 'pose_Rx', 'pose_Ry', 'pose_Rz']
    for x in df.columns:
        if '_r' in x and 'AU' in x:
            au.append(x)
    df = df[au]
    return df

# %%
# df = pd.DataFrame()
# df = getData("happiness_csv/", "happiness")
# df = processData(df)

# %%
df.to_csv("sadness/sadness_data.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-91756018c019> in <module>
# ----> 1 df.to_csv("sadness/sadness_data.csv")
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### Process Data

# %% [markdown]
# Get Single Person Data - keep the most occuring face_id
# Keep videos with more than 5 and less than 50 frames

# %%
df = pd.read_csv('disgust/disgust_data.csv')
df = df.drop(columns = 'Unnamed: 0')

# %%
videos = set(df['video'])
toRemove = []

for i in videos:
    lst = df[df['video']==i]['video'].tolist()
    if len(lst) <= 5:
        toRemove.append(i)
    df = df.drop(df[(df['video'] == i) & (df['video'] != max(lst,key=lst.count))].index)

for i in toRemove:
    videos.remove(i)
videos = list(videos)
df = df.drop(columns = 'face_id')

# %%
df[df['video'] == videos[10]].head(2)
# Out:
#       timestamp  video  gaze_angle_x  gaze_angle_y  pose_Rx  pose_Ry  pose_Rz  \
# 5294        0.0     12         0.304         0.256    0.188   -0.242   -0.027
# 5295        0.1     12         0.309         0.282    0.228   -0.243   -0.036
#
#       AU01_r  AU02_r  AU04_r  ...  AU10_r  AU12_r  AU14_r  AU15_r  AU17_r  \
# 5294    0.45     0.0     0.0  ...    1.07    0.70     0.0     0.0     0.0
# 5295    0.37     0.0     0.0  ...    0.77    0.51     0.0     0.0     0.0
#
#       AU20_r  AU23_r  AU25_r  AU26_r  AU45_r
# 5294    0.76     0.0    0.64    0.88     0.0
# 5295    0.54     0.0    0.66    0.90     0.0
#
# [2 rows x 24 columns]

# %%
len(videos)
# Out:
# 267

# %% [markdown]
# ## Clustering Au for Single Data Using DTW

# %% [markdown]
# Compute DTW score seperately -> sum up scores

# %%
cluster_data = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
cluster_data.head(2)
# Out:
#    AU01_r  AU02_r  AU04_r  AU05_r  AU06_r  AU07_r  AU09_r  AU10_r  AU12_r  \
# 0    1.65    0.35    0.11    1.09     0.0     0.0    0.53    0.80     0.0
# 1    1.68    0.48    0.06    1.37     0.0     0.0    0.60    0.64     0.0
#
#    AU14_r  AU15_r  AU17_r  AU20_r  AU23_r  AU25_r  AU26_r  AU45_r
# 0    1.72    0.71     0.0     0.0     0.0    0.73     0.0     0.0
# 1    2.01    0.70     0.0     0.0     0.0    0.95     0.0     0.0

# %% [markdown]
# #### Compute DTW based on similarities between each AU features

# %% [markdown]
# I will use normalized AU scoring to identify similar patterns between them. Because I am only looking a signal patterns, I will remove low AU scoring columns to avoid false positive scorings

# %% [markdown]
# ## Cluster Facial AU

# %% [markdown]
# #### Dropping Lower Scoring AU

# %%
def dropLowScoring(vid, df):
    # Getting video
    vid_idx = videos[vid]

    video_df = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
    video_df = video_df[df['video'] == vid_idx]
    
    # Removing videos with the lowest mean
    means = video_df.mean()
    percent20 = max(means)*0.2
    percent40 = max(means)*0.4

    low = video_df.loc[:, video_df.mean() < percent20]
    low = low.loc[:, video_df.max() < percent40]

    video_df = video_df.drop(columns = low.columns)
    return video_df

# %% [markdown]
# #### Get grouping of AU signal (selecting AU with largest value for grouping) using dtw
# eg. select AU6 -> finding AU's with smallest dtw to AU6

# %% [markdown]
# Grouping using DTW scoring (better for busy data)

# %%
from sklearn import preprocessing
def getGroupingDTW(vid, df):

    video_df = dropLowScoring(vid, df)
    
    sim_matrix = pd.DataFrame(index = video_df.columns)
    for key1 in video_df.columns:
        vid1 = []
        for key2 in video_df.columns: 
            a = df[df['video']==videos[vid]][key1]
            b = df[df['video']==videos[vid]][key2]
            a = np.array(a.div(max(a)))
            b = np.array(b.div(max(b)))
            d, cost_matrix, acc_cost_matrix, path = accelerated_dtw(a,b, dist='euclidean')
            vid1.append(d)
        sim_matrix[key1] = vid1.copy()

    
    highest = video_df.loc[:, video_df.max() == max(video_df.max())]
    idx = list(highest.columns)[0]
    grouping = sim_matrix[sim_matrix[idx] < sim_matrix[idx].quantile(0.3)][idx].index.tolist()
    grouping.insert(0,vid)
    print(grouping)
    return grouping

# %% [markdown]
# Grouping using Euklidean scoring (better for simple data)

# %%
from sklearn import preprocessing
def getGroupingAbs(vid, df):

    video_df = dropLowScoring(vid, df)
    
    sim_matrix = pd.DataFrame(index = video_df.columns)
    for key1 in video_df.columns:
        vid1 = []
        for key2 in video_df.columns:
            #normalize data to minimize effect of distancing
            a = df[df['video']==videos[vid]][key1]
            b = df[df['video']==videos[vid]][key2]
            a = np.array(a.div(max(a)))
            b = np.array(b.div(max(b)))
            d = sum(abs(a-b))
            vid1.append(d)
        sim_matrix[key1] = vid1.copy()


    highest = video_df.loc[:, video_df.max() == max(video_df.max())]
    idx = list(highest.columns)[0]
    grouping = sim_matrix[sim_matrix[idx] < sim_matrix[idx].quantile(0.3)][idx].index.tolist()
    grouping.insert(0,vid)
#     print(grouping)
    return grouping

# %% [markdown]
# ### Demonstrate grouping

# %%
# can change the (v) value and run the graphs to 
# see grouping of different clusters

v = 10

# %%
sample = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
sample = sample[df['video']==videos[v]]
sample.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# #### Sample Data containing similar signals after processing

# %%
dropLowScoring(v, df).plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
sample = dropLowScoring(v, df)
col = getGroupingDTW(v, df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title = 'dtw');
col = getGroupingAbs(v, df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title='abs');
# Out:
# [10, 'AU07_r', 'AU09_r', 'AU10_r']

# %% [markdown]
# #### show video

# %%
from IPython.display import Image, display

X = Image(url='sadness_Gif/{}.gif'.format(videos[v]))
display(X)
# Out:
# <img src="sadness_Gif/12.gif"/>

# %% [markdown]
# ## Grouping

# %% [markdown]
# #### Get AU grouping for entire dataframe

# %%
def getGrouping(df):
    groupings = []
    for i in range(len(videos)):
        group = getGroupingDTW(i, df)
        groupings.append(group.copy())
    return groupings

# %% [markdown]
# #### Group Similar Clusters together -return cluster dataframe

# %%
def groupCluster(groupings):
    data = []
    for i in groupings:
        data.append(i[1:])

    clusters = []
    N = [0]*len(videos)


    for elem in data:
        if len(elem) == 1:
            continue
        if elem not in clusters:
            clusters.append(elem)
        N[clusters.index(elem)] += 1

    N = N[:len(clusters)]

    cluster_df = pd.DataFrame()
    cluster_df['N'] =  N
    cluster_df['clusters'] = clusters
    cluster_df = cluster_df[cluster_df['N'] > 1].sort_values(by=['N'], ascending=False)
    return data, cluster_df

# %% [markdown]
# ## Find grouping for upper face AU

# %%
upper = ['AU01_r','AU02_r','AU04_r','AU05_r','AU06_r','AU07_r','AU09_r', 'AU45_r']
lower = ['AU10_r','AU12_r','AU14_r','AU15_r','AU17_r','AU20_r','AU23_r','AU25_r','AU26_r']
upper_au = df[upper]
lower_au = df[lower]
upper_df = df.drop(columns = lower)
lower_df = df.drop(columns = upper)

# %%
v = 8
sample = upper_au[df['video']==videos[v]]
sample.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %%
sample = dropLowScoring(v, upper_df)
col = getGroupingDTW(v, upper_df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title = 'dtw');
col = getGroupingAbs(v, upper_df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title='abs');
# Out:
# [8, 'AU01_r', 'AU04_r', 'AU09_r']

# %% [markdown]
# #### Get Grouping Data

# %% [markdown]
# Note: this may take a little while to run

# %%
# upper_groupings = getGrouping(upper_df)

# %%
upper_data, upper_cluster = groupCluster(upper_groupings)
upper_cluster.head()
# Out:
#      N          clusters
# 0   18  [AU06_r, AU07_r]
# 10  14  [AU04_r, AU06_r]
# 14  12  [AU05_r, AU07_r]
# 8   11  [AU01_r, AU05_r]
# 2   10  [AU01_r, AU02_r]

# %% [markdown]
# ## Cluster by lower face AU

# %% [markdown]
# #### Get Grouping Data

# %%
lower_groupings = getGrouping(lower_df)

# %%
lower_data, lower_cluster = groupCluster(lower_groupings)
lower_cluster.head(10)
# Out:
#      N          clusters
# 8   12  [AU25_r, AU26_r]
# 3   10  [AU10_r, AU25_r]
# 7    8  [AU10_r, AU17_r]
# 22   8  [AU10_r, AU26_r]
# 40   7  [AU10_r, AU20_r]
# 58   7  [AU10_r, AU12_r]
# 33   7  [AU15_r, AU17_r]
# 5    7  [AU23_r, AU26_r]
# 10   6  [AU12_r, AU25_r]
# 11   6  [AU15_r, AU26_r]

# %% [markdown]
# ## Cluster both data

# %%
groupings = getGrouping(df)
# Out:
# [0, 'AU06_r', 'AU07_r']
# [1, 'AU06_r', 'AU09_r', 'AU17_r', 'AU20_r']
# [2, 'AU04_r', 'AU07_r', 'AU09_r']
# [3, 'AU10_r', 'AU14_r', 'AU25_r', 'AU26_r']
# [4, 'AU05_r', 'AU06_r', 'AU15_r']
# [5, 'AU06_r', 'AU07_r', 'AU09_r', 'AU17_r', 'AU20_r']
# [6, 'AU05_r', 'AU15_r', 'AU23_r', 'AU26_r']
# [7, 'AU04_r', 'AU07_r', 'AU10_r']
# [8, 'AU05_r', 'AU06_r', 'AU09_r', 'AU14_r', 'AU23_r']
# [9, 'AU06_r', 'AU09_r', 'AU10_r', 'AU17_r']
# [10, 'AU07_r', 'AU09_r', 'AU10_r']
# [11, 'AU07_r', 'AU25_r', 'AU26_r']
# [12, 'AU04_r', 'AU05_r', 'AU10_r']
# [13, 'AU01_r', 'AU05_r', 'AU10_r', 'AU17_r']
# [14, 'AU06_r', 'AU12_r', 'AU25_r']
# [15, 'AU02_r', 'AU06_r', 'AU09_r']
# [16, 'AU04_r', 'AU06_r', 'AU07_r']
# [17, 'AU06_r', 'AU07_r', 'AU09_r', 'AU20_r']
# [18, 'AU01_r', 'AU04_r', 'AU06_r', 'AU12_r', 'AU14_r']
# [19, 'AU04_r', 'AU15_r', 'AU17_r']
# [20, 'AU04_r', 'AU07_r', 'AU09_r', 'AU15_r']
# [21, 'AU05_r', 'AU09_r', 'AU15_r', 'AU17_r', 'AU23_r']
# [22, 'AU06_r', 'AU07_r', 'AU26_r']
# [23, 'AU06_r', 'AU09_r', 'AU25_r']
# [24, 'AU04_r', 'AU10_r', 'AU15_r']
# [25, 'AU06_r', 'AU07_r', 'AU20_r']
# [26, 'AU06_r', 'AU25_r', 'AU26_r']
# [27, 'AU04_r', 'AU05_r', 'AU15_r']
# [28, 'AU01_r', 'AU05_r', 'AU07_r']
# [29, 'AU02_r', 'AU06_r', 'AU09_r', 'AU10_r', 'AU17_r']
# [30, 'AU04_r', 'AU23_r', 'AU26_r']
# [31, 'AU02_r', 'AU05_r', 'AU14_r', 'AU20_r', 'AU25_r']
# [32, 'AU04_r', 'AU10_r', 'AU25_r', 'AU45_r']
# [33, 'AU01_r', 'AU04_r', 'AU15_r', 'AU17_r', 'AU45_r']
# [34, 'AU06_r', 'AU12_r', 'AU26_r', 'AU45_r']
# [35, 'AU09_r', 'AU10_r', 'AU25_r']
# [36, 'AU04_r', 'AU07_r', 'AU26_r']
# [37, 'AU04_r', 'AU06_r', 'AU12_r', 'AU17_r']
# [38, 'AU01_r', 'AU04_r', 'AU05_r', 'AU07_r']
# [39, 'AU01_r', 'AU02_r', 'AU20_r']
# [40, 'AU04_r', 'AU15_r', 'AU20_r', 'AU25_r']
# [41, 'AU01_r', 'AU02_r', 'AU05_r', 'AU07_r', 'AU12_r']
# [42, 'AU04_r']
# [43, 'AU17_r', 'AU20_r', 'AU26_r', 'AU45_r']
# [44, 'AU10_r', 'AU12_r', 'AU17_r']
# [45, 'AU06_r', 'AU07_r', 'AU10_r', 'AU12_r']
# [46, 'AU01_r', 'AU05_r', 'AU15_r']
# [47, 'AU07_r', 'AU10_r', 'AU25_r']
# [48, 'AU04_r', 'AU10_r', 'AU26_r']
# [49, 'AU01_r', 'AU05_r', 'AU09_r', 'AU25_r']
# [50, 'AU06_r', 'AU10_r', 'AU17_r']
# [51, 'AU01_r', 'AU05_r', 'AU06_r', 'AU10_r']
# [52, 'AU06_r', 'AU12_r', 'AU14_r', 'AU25_r']
# [53, 'AU05_r', 'AU14_r', 'AU15_r', 'AU23_r']
# [54, 'AU25_r', 'AU26_r']
# [55, 'AU05_r', 'AU07_r', 'AU26_r']
# [56, 'AU04_r', 'AU14_r', 'AU25_r', 'AU26_r', 'AU45_r']
# [57, 'AU01_r', 'AU02_r', 'AU04_r', 'AU25_r']
# [58, 'AU01_r', 'AU02_r', 'AU10_r']
# [59, 'AU14_r', 'AU23_r', 'AU25_r', 'AU26_r', 'AU45_r']
# [60, 'AU07_r', 'AU20_r', 'AU26_r']
# [61, 'AU04_r', 'AU07_r', 'AU15_r', 'AU23_r']
# [62, 'AU10_r', 'AU26_r']
# [63, 'AU05_r', 'AU10_r', 'AU17_r', 'AU26_r']
# [64, 'AU04_r', 'AU17_r']
# [65, 'AU04_r', 'AU14_r', 'AU15_r', 'AU25_r', 'AU26_r']
# [66, 'AU01_r', 'AU04_r', 'AU06_r', 'AU10_r', 'AU12_r']
# [67, 'AU01_r', 'AU02_r', 'AU07_r', 'AU12_r']
# [68, 'AU10_r', 'AU26_r']
# [69, 'AU10_r', 'AU15_r', 'AU25_r']
# [70, 'AU01_r', 'AU07_r', 'AU15_r']
# [71, 'AU06_r', 'AU12_r', 'AU15_r', 'AU25_r', 'AU26_r']
# [72, 'AU01_r', 'AU02_r', 'AU04_r', 'AU10_r']
# [73, 'AU04_r', 'AU06_r', 'AU25_r']
# [74, 'AU04_r', 'AU07_r', 'AU25_r']
# [75, 'AU01_r', 'AU02_r', 'AU06_r', 'AU09_r', 'AU25_r']
# [76, 'AU05_r', 'AU15_r', 'AU25_r', 'AU26_r']
# [77, 'AU04_r', 'AU15_r', 'AU17_r']
# [78, 'AU04_r', 'AU06_r', 'AU07_r', 'AU09_r']
# [79, 'AU06_r', 'AU14_r', 'AU15_r', 'AU23_r', 'AU26_r']
# [80, 'AU06_r', 'AU15_r', 'AU20_r', 'AU26_r']
# [81, 'AU04_r', 'AU10_r', 'AU15_r', 'AU20_r']
# [82, 'AU05_r', 'AU06_r', 'AU10_r', 'AU25_r']
# [83, 'AU01_r', 'AU02_r', 'AU04_r', 'AU14_r', 'AU17_r']
# [84, 'AU05_r', 'AU06_r', 'AU15_r', 'AU17_r', 'AU23_r']
# [85, 'AU05_r', 'AU10_r']
# [86, 'AU01_r', 'AU05_r', 'AU15_r']
# [87, 'AU01_r', 'AU15_r', 'AU17_r', 'AU20_r']
# [88, 'AU26_r']
# [89, 'AU07_r', 'AU14_r', 'AU25_r']
# [90, 'AU10_r', 'AU14_r', 'AU17_r', 'AU20_r']
# [91, 'AU01_r', 'AU04_r', 'AU10_r']
# [92, 'AU02_r', 'AU04_r', 'AU25_r']
# [93, 'AU04_r', 'AU05_r', 'AU07_r']
# [94, 'AU01_r', 'AU10_r', 'AU12_r', 'AU15_r', 'AU17_r']
# [95, 'AU04_r', 'AU05_r', 'AU15_r', 'AU25_r']
# [96, 'AU12_r', 'AU14_r', 'AU25_r', 'AU26_r']
# [97, 'AU10_r', 'AU17_r', 'AU20_r']
# [98, 'AU04_r', 'AU20_r', 'AU23_r', 'AU25_r', 'AU26_r']
# [99, 'AU10_r', 'AU15_r', 'AU20_r']
# [100, 'AU04_r', 'AU10_r', 'AU17_r']
# [101, 'AU01_r', 'AU04_r', 'AU07_r', 'AU20_r', 'AU45_r']
# [102, 'AU04_r', 'AU07_r', 'AU25_r', 'AU26_r']
# [103, 'AU06_r', 'AU25_r', 'AU26_r']
# [104, 'AU07_r', 'AU10_r', 'AU12_r', 'AU26_r']
# [105, 'AU04_r', 'AU15_r', 'AU23_r']
# [106, 'AU01_r', 'AU04_r']
# [107, 'AU01_r', 'AU05_r', 'AU07_r', 'AU15_r']
# [108, 'AU14_r', 'AU23_r', 'AU26_r']
# [109, 'AU07_r', 'AU45_r']
# [110, 'AU04_r', 'AU06_r', 'AU09_r', 'AU17_r']
# [111, 'AU05_r', 'AU09_r', 'AU15_r', 'AU25_r']
# [112, 'AU14_r', 'AU15_r']
# [113, 'AU17_r']
# [114, 'AU01_r', 'AU02_r', 'AU14_r', 'AU45_r']
# [115, 'AU25_r', 'AU45_r']
# [116, 'AU02_r', 'AU05_r']
# [117, 'AU01_r', 'AU06_r', 'AU10_r', 'AU12_r', 'AU25_r']
# [118, 'AU01_r', 'AU10_r', 'AU20_r']
# [119, 'AU01_r', 'AU04_r', 'AU12_r']
# [120, 'AU10_r', 'AU15_r', 'AU17_r']
# [121, 'AU10_r', 'AU14_r', 'AU15_r', 'AU20_r', 'AU23_r']
# [122, 'AU01_r', 'AU04_r', 'AU09_r']
# [123, 'AU04_r', 'AU15_r', 'AU26_r']
# [124, 'AU07_r', 'AU09_r', 'AU10_r', 'AU12_r', 'AU26_r']
# [125, 'AU01_r', 'AU07_r', 'AU09_r']
# [126, 'AU04_r', 'AU05_r', 'AU45_r']
# [127, 'AU06_r', 'AU10_r', 'AU12_r', 'AU20_r']
# [128, 'AU05_r', 'AU10_r']
# [129, 'AU05_r', 'AU15_r']
# [130, 'AU01_r', 'AU04_r', 'AU45_r']
# [131, 'AU09_r', 'AU10_r', 'AU26_r']
# [132, 'AU01_r', 'AU09_r', 'AU15_r']
# [133, 'AU05_r', 'AU12_r', 'AU20_r']
# [134, 'AU06_r', 'AU10_r', 'AU12_r', 'AU45_r']
# [135, 'AU04_r', 'AU09_r', 'AU10_r']
# [136, 'AU15_r', 'AU23_r', 'AU26_r']
# [137, 'AU04_r', 'AU09_r', 'AU10_r', 'AU12_r']
# [138, 'AU26_r']
# [139, 'AU04_r', 'AU12_r', 'AU14_r']
# [140, 'AU01_r', 'AU05_r', 'AU06_r', 'AU10_r', 'AU20_r']
# [141, 'AU02_r', 'AU05_r', 'AU15_r']
# [142, 'AU01_r', 'AU02_r', 'AU23_r']
# [143, 'AU06_r', 'AU07_r', 'AU25_r']
# [144, 'AU05_r']
# [145, 'AU10_r', 'AU25_r', 'AU26_r']
# [146, 'AU06_r', 'AU07_r', 'AU09_r', 'AU12_r']
# [147, 'AU06_r', 'AU10_r', 'AU17_r', 'AU20_r']
# [148, 'AU05_r', 'AU09_r', 'AU14_r', 'AU17_r']
# [149, 'AU04_r', 'AU06_r', 'AU15_r']
# [150, 'AU07_r']
# [151, 'AU15_r', 'AU26_r']
# [152, 'AU07_r', 'AU10_r', 'AU17_r', 'AU20_r', 'AU45_r']
# [153, 'AU01_r', 'AU15_r', 'AU17_r']
# [154, 'AU10_r', 'AU17_r', 'AU26_r']
# [155, 'AU01_r', 'AU04_r', 'AU15_r', 'AU25_r', 'AU26_r']
# [156, 'AU14_r', 'AU25_r', 'AU26_r']
# [157, 'AU26_r']
# [158, 'AU07_r', 'AU12_r', 'AU26_r']
# [159, 'AU04_r', 'AU25_r', 'AU26_r']
# [160, 'AU07_r', 'AU15_r', 'AU20_r', 'AU23_r']
# [161, 'AU01_r', 'AU10_r', 'AU15_r']
# [162, 'AU01_r', 'AU06_r', 'AU25_r']
# [163, 'AU05_r']
# [164, 'AU05_r']
# [165, 'AU05_r', 'AU25_r', 'AU26_r']
# [166, 'AU06_r', 'AU07_r']
# [167, 'AU04_r', 'AU06_r', 'AU07_r']
# [168, 'AU04_r', 'AU06_r', 'AU45_r']
# [169, 'AU06_r', 'AU10_r', 'AU12_r']
# [170, 'AU10_r', 'AU26_r']
# [171, 'AU04_r', 'AU05_r', 'AU09_r']
# [172, 'AU01_r', 'AU02_r']
# [173, 'AU01_r', 'AU06_r', 'AU07_r', 'AU17_r', 'AU26_r']
# [174, 'AU04_r', 'AU06_r', 'AU10_r', 'AU25_r']
# [175, 'AU01_r', 'AU02_r', 'AU05_r']
# [176, 'AU05_r', 'AU10_r', 'AU14_r', 'AU15_r', 'AU20_r']
# [177, 'AU04_r', 'AU05_r', 'AU17_r']
# [178, 'AU15_r', 'AU25_r', 'AU26_r']
# [179, 'AU04_r', 'AU25_r']
# [180, 'AU01_r', 'AU14_r', 'AU15_r']
# [181, 'AU12_r', 'AU25_r', 'AU26_r']
# [182, 'AU05_r', 'AU25_r', 'AU26_r']
# [183, 'AU15_r', 'AU17_r', 'AU20_r']
# [184, 'AU01_r', 'AU02_r', 'AU04_r', 'AU05_r']
# [185, 'AU05_r', 'AU07_r', 'AU26_r']
# [186, 'AU10_r', 'AU25_r', 'AU26_r']
# [187, 'AU23_r', 'AU26_r', 'AU45_r']
# [188, 'AU12_r', 'AU14_r', 'AU15_r', 'AU23_r', 'AU45_r']
# [189, 'AU04_r', 'AU06_r']
# [190, 'AU01_r', 'AU02_r', 'AU10_r', 'AU25_r', 'AU26_r']
# [191, 'AU01_r', 'AU02_r', 'AU05_r', 'AU06_r', 'AU14_r']
# [192, 'AU02_r', 'AU06_r', 'AU10_r', 'AU15_r']
# [193, 'AU02_r', 'AU07_r', 'AU17_r', 'AU26_r']
# [194, 'AU02_r', 'AU25_r', 'AU26_r']
# [195, 'AU10_r', 'AU14_r', 'AU25_r']
# [196, 'AU05_r', 'AU09_r', 'AU20_r', 'AU23_r', 'AU26_r']
# [197, 'AU04_r', 'AU15_r', 'AU20_r']
# [198, 'AU06_r', 'AU07_r', 'AU12_r']
# [199, 'AU05_r', 'AU20_r', 'AU45_r']
# [200, 'AU06_r', 'AU07_r', 'AU10_r', 'AU26_r']
# [201, 'AU01_r', 'AU05_r', 'AU15_r']
# [202, 'AU04_r', 'AU09_r', 'AU15_r']
# [203, 'AU02_r', 'AU14_r', 'AU20_r', 'AU23_r', 'AU45_r']
# [204, 'AU05_r', 'AU10_r', 'AU17_r']
# [205, 'AU14_r', 'AU17_r', 'AU26_r', 'AU45_r']
# [206, 'AU14_r', 'AU15_r', 'AU26_r']
# [207, 'AU01_r', 'AU05_r', 'AU06_r', 'AU15_r']
# [208, 'AU01_r', 'AU15_r', 'AU20_r']
# [209, 'AU01_r', 'AU04_r', 'AU06_r', 'AU14_r', 'AU26_r']
# [210, 'AU01_r', 'AU02_r', 'AU26_r']
# [211, 'AU01_r', 'AU15_r', 'AU20_r']
# [212, 'AU04_r', 'AU10_r', 'AU15_r', 'AU23_r', 'AU25_r']
# [213, 'AU05_r', 'AU07_r', 'AU20_r']
# [214, 'AU02_r', 'AU17_r', 'AU23_r']
# [215, 'AU05_r', 'AU10_r', 'AU12_r', 'AU14_r']
# [216, 'AU15_r', 'AU26_r']
# [217, 'AU06_r', 'AU10_r', 'AU25_r', 'AU26_r']
# [218, 'AU04_r', 'AU07_r', 'AU15_r', 'AU25_r']
# [219, 'AU01_r', 'AU02_r', 'AU05_r', 'AU12_r']
# [220, 'AU10_r', 'AU14_r', 'AU25_r', 'AU26_r']
# [221, 'AU04_r', 'AU06_r', 'AU07_r', 'AU09_r', 'AU10_r']
# [222, 'AU04_r', 'AU17_r', 'AU45_r']
# [223, 'AU15_r', 'AU25_r', 'AU26_r', 'AU45_r']
# [224, 'AU09_r', 'AU17_r', 'AU26_r']
# [225, 'AU05_r', 'AU07_r', 'AU09_r', 'AU10_r']
# [226, 'AU04_r', 'AU10_r', 'AU12_r', 'AU17_r', 'AU20_r']
# [227, 'AU15_r', 'AU17_r']
# [228, 'AU02_r', 'AU17_r', 'AU26_r', 'AU45_r']
# [229, 'AU04_r', 'AU10_r', 'AU15_r']
# [230, 'AU01_r', 'AU02_r', 'AU14_r', 'AU20_r', 'AU26_r']
# [231, 'AU07_r', 'AU10_r', 'AU26_r']
# [232, 'AU25_r', 'AU26_r']
# [233, 'AU05_r', 'AU15_r', 'AU23_r']
# [234, 'AU01_r', 'AU07_r', 'AU15_r', 'AU20_r']
# [235, 'AU05_r', 'AU06_r', 'AU07_r']
# [236, 'AU05_r', 'AU15_r', 'AU17_r']
# [237, 'AU01_r', 'AU02_r', 'AU05_r', 'AU09_r', 'AU14_r']
# [238, 'AU15_r', 'AU25_r']
# [239, 'AU06_r', 'AU10_r', 'AU12_r', 'AU14_r']
# [240, 'AU01_r', 'AU02_r', 'AU05_r', 'AU15_r']
# [241, 'AU01_r', 'AU02_r', 'AU25_r']
# [242, 'AU01_r', 'AU14_r', 'AU23_r', 'AU25_r', 'AU26_r']
# [243, 'AU06_r', 'AU10_r', 'AU12_r', 'AU14_r', 'AU15_r']
# [244, 'AU06_r', 'AU07_r', 'AU09_r', 'AU26_r']
# [245, 'AU05_r', 'AU06_r', 'AU07_r']
# [246, 'AU07_r', 'AU09_r', 'AU10_r', 'AU20_r']
# [247, 'AU02_r', 'AU23_r']
# [248, 'AU01_r', 'AU05_r', 'AU15_r']
# [249, 'AU01_r', 'AU05_r', 'AU15_r']
# [250, 'AU01_r', 'AU02_r', 'AU05_r', 'AU09_r', 'AU14_r']
# [251, 'AU04_r', 'AU14_r', 'AU15_r']
# [252, 'AU06_r', 'AU09_r', 'AU14_r']
# [253, 'AU01_r', 'AU14_r', 'AU17_r']
# [254, 'AU01_r', 'AU02_r', 'AU05_r']
# [255, 'AU25_r', 'AU26_r']
# [256, 'AU05_r', 'AU15_r']
# [257, 'AU12_r', 'AU14_r', 'AU25_r', 'AU45_r']
# [258, 'AU01_r', 'AU05_r', 'AU15_r']
# [259, 'AU20_r', 'AU45_r']
# [260, 'AU05_r', 'AU15_r', 'AU17_r', 'AU23_r', 'AU26_r']
# [261, 'AU01_r', 'AU02_r', 'AU04_r', 'AU15_r']
# [262, 'AU04_r', 'AU15_r', 'AU23_r']
# [263, 'AU04_r', 'AU06_r', 'AU10_r']
# [264, 'AU01_r', 'AU05_r']
# [265, 'AU02_r', 'AU25_r', 'AU26_r']
# [266, 'AU01_r', 'AU02_r', 'AU05_r']

# %%
full_data, cluster = groupCluster(groupings)
cluster.head(10)
# Out:
#      N                  clusters
# 45   6  [AU01_r, AU05_r, AU15_r]
# 158  3  [AU01_r, AU02_r, AU05_r]
# 53   3          [AU25_r, AU26_r]
# 61   3          [AU10_r, AU26_r]
# 0    2          [AU06_r, AU07_r]
# 121  2          [AU05_r, AU15_r]
# 209  2  [AU05_r, AU06_r, AU07_r]
# 187  2  [AU01_r, AU15_r, AU20_r]
# 174  2  [AU02_r, AU25_r, AU26_r]
# 151  2  [AU05_r, AU25_r, AU26_r]

# %% [markdown]
# ### Graphing AU Relationship

# %%
def getRelation(au_data, au_label):
    
    percentage = pd.DataFrame(index = au_label)   
    for au in au_label:
        au_cluster = []
        # for i in lower_au_label:
        for data in au_data:
            if au in data:
                au_cluster.append(data)

        single_au = 0
        other_au = []
        for i in au_cluster:
            if i == [au]:
                single_au += 1
            else:
                for other in i:
                    if other != au:
                        other_au.append(other)

        length = len(other_au) + single_au
        au_percentage = []

        for i in au_label:
            if i == au:
                au_percentage.append(single_au/length)
            else:
                au_percentage.append(other_au.count(i)/length)


        percentage[au] = au_percentage
        percentage.columns.name='main_au'
        percentage.index.name='au_likelihood'
    percentage.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %%
au_label = upper_au.columns.tolist()+lower_au.columns.tolist()

au_data = upper_data
getRelation(upper_data, upper_au.columns.tolist())
getRelation(lower_data, lower_au.columns.tolist())
getRelation(full_data, au_label)

# percentage.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
