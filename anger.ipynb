# %%
#imports
import pandas as pd     
import matplotlib.pyplot as plt    
# %matplotlib inline
import seaborn as sns    
import numpy as np
from sklearn.mixture import GaussianMixture as GMM
import os
sns.set(style="darkgrid")
from math import pi
from glob import glob
import re
import math
import scipy.interpolate as interp
from tslearn.metrics import dtw, dtw_path
from dtw import dtw,accelerated_dtw

# %% [markdown]
# #### Get Data

# %%
# Reference: https://perials.com/getting-csv-files-directory-subdirectories-using-python/
def getData(PATH, name):
#     PATH = "happinessData/"

    EXT = "*.csv"
    files = [file for path, subdir, files in os.walk(PATH)
                for file in glob(os.path.join(path, EXT))]
    l = []
    for f in files:
        df = pd.read_csv(f)
        result = re.search('/(.*).csv', f)
#         r = re.search('/(.*)',str(result.group(1)))
        video = result.group(1)
        df['video'] = np.full(len(df), video, dtype = int)
        l.append(df)
    df = pd.concat(l, ignore_index=True)
    df['name'] = name
    df = df.rename(columns=lambda x: x.strip())
    return df

# %% [markdown]
# #### Processing Data

# %%
def processData(df):
    df = df[df['success'] != 0]
    df = df[df['confidence'] > 0.80]
    # extracting features
    au = [ 'timestamp','face_id','video', 'gaze_angle_x', 'gaze_angle_y', 'pose_Rx', 'pose_Ry', 'pose_Rz']
    for x in df.columns:
        if '_r' in x and 'AU' in x:
            au.append(x)
    df = df[au]
    return df

# %%
# df = pd.DataFrame()
# df = getData("happiness_csv/", "happiness")
# df = processData(df)

# %%
df.to_csv("anger/anger_data.csv")

# %% [markdown]
# #### Process Data

# %% [markdown]
# Get Single Person Data - keep the most occuring face_id
# Keep videos with more than 5 and less than 50 frames

# %%
df = pd.read_csv('sadness/sadness_data.csv')
df = df.drop(columns = 'Unnamed: 0')

# %%
videos = set(df['video'])
toRemove = []

for i in videos:
    lst = df[df['video']==i]['video'].tolist()
    if len(lst) <= 5:
        toRemove.append(i)
    df = df.drop(df[(df['video'] == i) & (df['video'] != max(lst,key=lst.count))].index)

for i in toRemove:
    videos.remove(i)
videos = list(videos)
df = df.drop(columns = 'face_id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-149-9867ada48922> in <module>
#      11     videos.remove(i)
#      12 videos = list(videos)
# ---> 13 df = df.drop(columns = 'face_id')
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['face_id'] not found in axis"

# %%
df[df['video'] == videos[10]].head(2)

# %%
len(videos)

# %% [markdown]
# ## Clustering Au for Single Data Using DTW

# %% [markdown]
# Compute DTW score seperately -> sum up scores

# %%
cluster_data = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
cluster_data.head(2)

# %% [markdown]
# #### Compute DTW based on similarities between each AU features

# %% [markdown]
# I will use normalized AU scoring to identify similar patterns between them. Because I am only looking a signal patterns, I will remove low AU scoring columns to avoid false positive scorings

# %% [markdown]
# ## Cluster Facial AU

# %% [markdown]
# #### Dropping Lower Scoring AU

# %%
def dropLowScoring(vid, df):
    # Getting video
    vid_idx = videos[vid]

    video_df = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
    video_df = video_df[df['video'] == vid_idx]
    
    # Removing videos with the lowest mean
    means = video_df.mean()
    percent20 = max(means)*0.2
    percent40 = max(means)*0.4

    low = video_df.loc[:, video_df.mean() < percent20]
    low = low.loc[:, video_df.max() < percent40]

    video_df = video_df.drop(columns = low.columns)
    return video_df

# %% [markdown]
# #### Get grouping of AU signal (selecting AU with largest value for grouping) using dtw
# eg. select AU6 -> finding AU's with smallest dtw to AU6

# %% [markdown]
# Grouping using DTW scoring (better for busy data)

# %%
from sklearn import preprocessing
def getGroupingDTW(vid, df):

    video_df = dropLowScoring(vid, df)
    
    sim_matrix = pd.DataFrame(index = video_df.columns)
    for key1 in video_df.columns:
        vid1 = []
        for key2 in video_df.columns: 
            a = df[df['video']==videos[vid]][key1]
            b = df[df['video']==videos[vid]][key2]
            a = np.array(a.div(max(a)))
            b = np.array(b.div(max(b)))
            d, cost_matrix, acc_cost_matrix, path = accelerated_dtw(a,b, dist='euclidean')
            vid1.append(d)
        sim_matrix[key1] = vid1.copy()

    
    highest = video_df.loc[:, video_df.max() == max(video_df.max())]
    idx = list(highest.columns)[0]
    grouping = sim_matrix[sim_matrix[idx] < sim_matrix[idx].quantile(0.3)][idx].index.tolist()
    grouping.insert(0,vid)
    print(grouping)
    return grouping

# %% [markdown]
# Grouping using Euklidean scoring (better for simple data)

# %%
from sklearn import preprocessing
def getGroupingAbs(vid, df):

    video_df = dropLowScoring(vid, df)
    
    sim_matrix = pd.DataFrame(index = video_df.columns)
    for key1 in video_df.columns:
        vid1 = []
        for key2 in video_df.columns:
            #normalize data to minimize effect of distancing
            a = df[df['video']==videos[vid]][key1]
            b = df[df['video']==videos[vid]][key2]
            a = np.array(a.div(max(a)))
            b = np.array(b.div(max(b)))
            d = sum(abs(a-b))
            vid1.append(d)
        sim_matrix[key1] = vid1.copy()


    highest = video_df.loc[:, video_df.max() == max(video_df.max())]
    idx = list(highest.columns)[0]
    grouping = sim_matrix[sim_matrix[idx] < sim_matrix[idx].quantile(0.3)][idx].index.tolist()
    grouping.insert(0,vid)
#     print(grouping)
    return grouping

# %% [markdown]
# ### Demonstrate grouping

# %%
# can change the (v) value and run the graphs to 
# see grouping of different clusters

v = 37

# %%
sample = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
sample = sample[df['video']==videos[v]]
sample.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# #### Sample Data containing similar signals after processing

# %%
dropLowScoring(v, df).plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
sample = dropLowScoring(v, df)
col = getGroupingDTW(v, df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title = 'dtw');
col = getGroupingAbs(v, df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title='eukliean');
# Out:
# [37, 'AU01_r', 'AU04_r', 'AU15_r']

# %% [markdown]
# #### show video

# %%
from IPython.display import Image, display

X = Image(url='sadness_Gif/{}.gif'.format(videos[v]))
display(X)
# Out:
# <img src="sadness_Gif/66.gif"/>

# %% [markdown]
# ## Grouping

# %% [markdown]
# #### Get AU grouping for entire dataframe

# %%
def getGrouping(df):
    groupings = []
    for i in range(len(videos)):
        group = getGroupingDTW(i, df)
        groupings.append(group.copy())
    return groupings

# %% [markdown]
# #### Group Similar Clusters together -return cluster dataframe

# %%
def groupCluster(groupings):
    data = []
    for i in groupings:
        data.append(i[1:])

    clusters = []
    N = [0]*len(videos)


    for elem in data:
        if len(elem) == 1:
            continue
        if elem not in clusters:
            clusters.append(elem)
        N[clusters.index(elem)] += 1

    N = N[:len(clusters)]

    cluster_df = pd.DataFrame()
    cluster_df['N'] =  N
    cluster_df['clusters'] = clusters
    cluster_df = cluster_df[cluster_df['N'] > 1].sort_values(by=['N'], ascending=False)
    return data, cluster_df

# %% [markdown]
# ## Find grouping for upper face AU

# %%
upper = ['AU01_r','AU02_r','AU04_r','AU05_r','AU06_r','AU07_r','AU09_r', 'AU45_r']
lower = ['AU10_r','AU12_r','AU14_r','AU15_r','AU17_r','AU20_r','AU23_r','AU25_r','AU26_r']
upper_au = df[upper]
lower_au = df[lower]
upper_df = df.drop(columns = lower)
lower_df = df.drop(columns = upper)

# %%
v = 9
sample = upper_au[df['video']==videos[v]]
sample.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %%
sample = dropLowScoring(v, upper_df)
col = getGroupingDTW(v, upper_df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title = 'dtw');
col = getGroupingAbs(v, upper_df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title='abs');
# Out:
# [9, 'AU04_r', 'AU09_r']

# %%
from IPython.display import Image, display

X = Image(url='sadness_Gif/{}.gif'.format(videos[v]))
display(X)
# Out:
# <img src="sadness_Gif/16.gif"/>

# %% [markdown]
# #### Get Grouping Data

# %% [markdown]
# Note: this may take a little while to run

# %%
upper_groupings = getGrouping(upper_df)
# Out:
# [0, 'AU04_r', 'AU07_r']
# [1, 'AU05_r', 'AU07_r', 'AU09_r']
# [2, 'AU06_r', 'AU09_r']
# [3, 'AU04_r', 'AU45_r']
# [4, 'AU01_r', 'AU45_r']
# [5, 'AU02_r']
# [6, 'AU45_r']
# [7, 'AU06_r', 'AU07_r']
# [8, 'AU04_r', 'AU06_r']
# [9, 'AU04_r', 'AU09_r']
# [10, 'AU05_r', 'AU06_r']
# [11, 'AU01_r']
# [12, 'AU04_r', 'AU06_r', 'AU07_r']
# [13, 'AU01_r', 'AU45_r']
# [14, 'AU02_r', 'AU05_r']
# [15, 'AU07_r', 'AU09_r']
# [16, 'AU05_r']
# [17, 'AU01_r', 'AU04_r']
# [18, 'AU06_r', 'AU09_r']
# [19, 'AU01_r', 'AU06_r', 'AU07_r']
# [20, 'AU04_r']
# [21, 'AU05_r']
# [22, 'AU06_r', 'AU09_r']
# [23, 'AU07_r']
# [24, 'AU01_r', 'AU07_r']
# [25, 'AU01_r', 'AU06_r']
# [26, 'AU02_r', 'AU05_r']
# [27, 'AU05_r', 'AU45_r']
# [28, 'AU07_r', 'AU45_r']
# [29, 'AU01_r']
# [30, 'AU01_r', 'AU02_r', 'AU07_r']
# [31, 'AU06_r']
# [32, 'AU01_r']
# [33, 'AU04_r', 'AU06_r']
# [34, 'AU02_r', 'AU05_r']
# [35, 'AU04_r', 'AU06_r']
# [36, 'AU06_r', 'AU07_r']
# [37, 'AU01_r', 'AU04_r']
# [38, 'AU06_r', 'AU07_r']
# [39, 'AU04_r', 'AU45_r']
# [40, 'AU02_r', 'AU09_r']
# [41, 'AU01_r', 'AU05_r']
# [42, 'AU06_r', 'AU09_r']
# [43, 'AU04_r', 'AU45_r']
# [44, 'AU01_r', 'AU04_r']
# [45, 'AU04_r', 'AU06_r']
# [46, 'AU01_r', 'AU04_r']
# [47, 'AU01_r', 'AU06_r']
# [48, 'AU02_r', 'AU05_r']
# [49, 'AU45_r']
# [50, 'AU02_r', 'AU07_r']
# [51, 'AU02_r']
# [52, 'AU05_r', 'AU09_r']
# [53, 'AU02_r', 'AU04_r', 'AU09_r']
# [54, 'AU02_r', 'AU05_r']
# [55, 'AU01_r', 'AU06_r']
# [56, 'AU01_r']
# [57, 'AU01_r', 'AU07_r']
# [58, 'AU02_r']
# [59, 'AU06_r', 'AU07_r']
# [60, 'AU07_r', 'AU09_r']
# [61, 'AU02_r', 'AU04_r']
# [62, 'AU04_r']
# [63, 'AU06_r', 'AU09_r']
# [64, 'AU04_r', 'AU06_r']
# [65, 'AU04_r', 'AU09_r']
# [66, 'AU05_r']
# [67, 'AU06_r', 'AU07_r']
# [68, 'AU05_r']
# [69, 'AU04_r', 'AU07_r']
# [70, 'AU04_r', 'AU07_r']
# [71, 'AU04_r', 'AU05_r', 'AU07_r']
# [72, 'AU01_r', 'AU05_r']
# [73, 'AU01_r', 'AU06_r']
# [74, 'AU04_r']
# [75, 'AU04_r', 'AU45_r']
# [76, 'AU02_r', 'AU07_r']
# [77, 'AU45_r']
# [78, 'AU04_r', 'AU45_r']
# [79, 'AU45_r']
# [80, 'AU45_r']
# [81, 'AU06_r', 'AU09_r']
# [82, 'AU01_r', 'AU05_r', 'AU09_r']
# [83, 'AU01_r']
# [84, 'AU01_r', 'AU02_r']
# [85, 'AU05_r', 'AU07_r']
# [86, 'AU04_r', 'AU07_r', 'AU09_r']
# [87, 'AU06_r', 'AU07_r']
# [88, 'AU01_r', 'AU07_r']
# [89, 'AU01_r', 'AU04_r']
# [90, 'AU45_r']
# [91, 'AU04_r']
# [92, 'AU04_r', 'AU09_r']
# [93, 'AU01_r']
# [94, 'AU04_r', 'AU45_r']
# [95, 'AU06_r', 'AU45_r']
# [96, 'AU01_r']
# [97, 'AU05_r']
# [98, 'AU01_r']
# [99, 'AU01_r']
# [100, 'AU07_r', 'AU45_r']
# [101, 'AU06_r', 'AU07_r', 'AU09_r']
# [102, 'AU02_r']
# [103, 'AU02_r', 'AU05_r']
# [104, 'AU01_r']
# [105, 'AU01_r', 'AU05_r']
# [106, 'AU04_r', 'AU07_r']
# [107, 'AU04_r', 'AU06_r']
# [108, 'AU05_r', 'AU06_r', 'AU09_r']
# [109, 'AU01_r', 'AU07_r']
# [110, 'AU01_r', 'AU05_r']
# [111, 'AU07_r']
# [112, 'AU45_r']
# [113, 'AU01_r', 'AU04_r']
# [114, 'AU04_r', 'AU09_r']
# [115, 'AU01_r']
# [116, 'AU05_r', 'AU07_r']
# [117, 'AU07_r']
# [118, 'AU07_r', 'AU09_r']
# [119, 'AU01_r', 'AU06_r']
# [120, 'AU02_r', 'AU04_r']
# [121, 'AU02_r', 'AU04_r']
# [122, 'AU01_r']
# [123, 'AU04_r']
# [124, 'AU05_r', 'AU09_r']
# [125, 'AU45_r']
# [126, 'AU04_r', 'AU07_r']
# [127, 'AU06_r', 'AU09_r']
# [128, 'AU04_r', 'AU45_r']
# [129, 'AU01_r', 'AU02_r']
# [130, 'AU06_r', 'AU07_r']
# [131, 'AU04_r']
# [132]
# [133, 'AU06_r', 'AU07_r']
# [134, 'AU04_r', 'AU09_r']
# [135, 'AU01_r', 'AU02_r', 'AU05_r']
# [136, 'AU09_r', 'AU45_r']
# [137, 'AU01_r', 'AU04_r']
# [138, 'AU04_r', 'AU07_r']
# [139, 'AU02_r']
# [140, 'AU01_r', 'AU05_r']
# [141, 'AU01_r', 'AU02_r']
# [142, 'AU01_r', 'AU04_r', 'AU05_r']
# [143, 'AU01_r']
# [144, 'AU01_r', 'AU02_r', 'AU04_r']
# [145, 'AU01_r', 'AU04_r']
# [146, 'AU45_r']
# [147, 'AU04_r']
# [148, 'AU04_r']
# [149, 'AU06_r', 'AU07_r']
# [150, 'AU01_r', 'AU02_r', 'AU05_r']
# [151, 'AU01_r', 'AU02_r']
# [152, 'AU04_r', 'AU07_r']
# [153, 'AU01_r', 'AU02_r']
# [154, 'AU01_r']
# [155, 'AU04_r', 'AU05_r']
# [156, 'AU06_r', 'AU45_r']
# [157, 'AU01_r', 'AU05_r', 'AU06_r']
# [158, 'AU01_r']
# [159, 'AU01_r', 'AU05_r']
# [160, 'AU04_r']
# [161, 'AU01_r', 'AU02_r']
# [162, 'AU01_r']
# [163, 'AU01_r', 'AU04_r']
# [164, 'AU45_r']
# [165, 'AU05_r']
# [166, 'AU45_r']
# [167, 'AU04_r', 'AU45_r']
# [168, 'AU05_r']
# [169, 'AU02_r', 'AU04_r']
# [170, 'AU01_r', 'AU04_r']
# [171, 'AU04_r']
# [172, 'AU02_r', 'AU06_r']
# [173, 'AU05_r', 'AU06_r']
# [174, 'AU04_r']
# [175, 'AU06_r', 'AU07_r']
# [176, 'AU04_r', 'AU05_r']
# [177, 'AU06_r']
# [178, 'AU45_r']
# [179, 'AU01_r']
# [180, 'AU07_r', 'AU09_r']
# [181, 'AU01_r', 'AU04_r']
# [182, 'AU07_r', 'AU09_r']
# [183, 'AU01_r', 'AU02_r', 'AU45_r']
# [184, 'AU01_r', 'AU06_r']
# [185, 'AU01_r']
# [186, 'AU02_r']
# [187, 'AU01_r', 'AU05_r']
# [188, 'AU06_r']
# [189, 'AU04_r', 'AU07_r']
# [190, 'AU01_r', 'AU04_r', 'AU07_r']
# [191, 'AU01_r', 'AU05_r']
# [192, 'AU02_r', 'AU05_r', 'AU45_r']
# [193, 'AU09_r']
# [194, 'AU02_r']
# [195, 'AU04_r', 'AU09_r']
# [196, 'AU01_r', 'AU04_r']
# [197, 'AU07_r']
# [198, 'AU05_r']
# [199, 'AU04_r', 'AU07_r']
# [200, 'AU04_r', 'AU06_r', 'AU07_r']
# [201, 'AU04_r', 'AU06_r']
# [202, 'AU05_r', 'AU45_r']
# [203, 'AU06_r', 'AU07_r']
# [204, 'AU02_r']
# [205, 'AU06_r', 'AU07_r']
# [206, 'AU04_r', 'AU06_r']
# [207, 'AU01_r', 'AU04_r']
# [208, 'AU01_r']
# [209, 'AU01_r', 'AU04_r']
# [210, 'AU06_r', 'AU09_r', 'AU45_r']
# [211, 'AU06_r', 'AU45_r']
# [212, 'AU01_r', 'AU05_r', 'AU09_r']
# [213, 'AU01_r', 'AU04_r', 'AU45_r']
# [214, 'AU01_r']
# [215, 'AU02_r', 'AU06_r']
# [216, 'AU04_r']
# [217, 'AU04_r']
# [218, 'AU06_r', 'AU07_r']
# [219, 'AU04_r', 'AU07_r']
# [220, 'AU07_r', 'AU09_r']
# [221, 'AU01_r', 'AU04_r']
# [222, 'AU04_r', 'AU09_r', 'AU45_r']
# [223, 'AU04_r']
# [224, 'AU04_r', 'AU06_r']
# [225, 'AU01_r', 'AU04_r']
# [226, 'AU01_r', 'AU04_r']
# [227, 'AU05_r']
# [228, 'AU05_r']
# [229, 'AU01_r', 'AU07_r']
# [230, 'AU04_r', 'AU07_r', 'AU09_r']
# [231, 'AU05_r', 'AU45_r']
# [232, 'AU01_r', 'AU45_r']
# [233, 'AU04_r', 'AU06_r']
# [234, 'AU07_r']
# [235, 'AU01_r', 'AU04_r']
# [236, 'AU04_r', 'AU05_r']
# [237, 'AU02_r', 'AU04_r']
# [238, 'AU01_r', 'AU05_r']
# [239, 'AU05_r']
# [240, 'AU06_r', 'AU07_r', 'AU09_r']
# [241, 'AU01_r', 'AU05_r']
# [242, 'AU01_r']
# [243, 'AU04_r', 'AU05_r', 'AU06_r']
# [244, 'AU01_r', 'AU45_r']
# [245, 'AU45_r']
# [246, 'AU06_r', 'AU07_r']
# [247, 'AU07_r', 'AU09_r']
# [248, 'AU04_r', 'AU45_r']
# [249, 'AU07_r', 'AU09_r']
# [250, 'AU01_r', 'AU04_r']
# [251, 'AU04_r']
# [252, 'AU01_r', 'AU06_r']
# [253, 'AU05_r', 'AU09_r']
# [254, 'AU01_r', 'AU09_r']
# [255, 'AU01_r', 'AU07_r']
# [256, 'AU01_r']
# [257, 'AU45_r']
# [258, 'AU01_r', 'AU02_r']
# [259, 'AU04_r']
# [260, 'AU06_r', 'AU07_r']
# [261, 'AU04_r']
# [262, 'AU01_r', 'AU05_r']
# [263, 'AU05_r']
# [264, 'AU05_r', 'AU45_r']
# [265, 'AU06_r', 'AU07_r']
# [266, 'AU04_r', 'AU09_r', 'AU45_r']
# [267, 'AU05_r']
# [268, 'AU01_r', 'AU05_r']
# [269, 'AU04_r']
# [270, 'AU05_r']
# [271, 'AU04_r']
# [272, 'AU07_r', 'AU09_r']
# [273, 'AU07_r', 'AU45_r']
# [274, 'AU02_r', 'AU04_r']
# [275, 'AU01_r']
# [276, 'AU06_r', 'AU09_r']
# [277, 'AU06_r', 'AU07_r']
# [278, 'AU04_r']
# [279, 'AU01_r', 'AU07_r']
# [280, 'AU01_r', 'AU02_r', 'AU05_r']
# [281, 'AU09_r', 'AU45_r']
# [282, 'AU05_r', 'AU45_r']
# [283, 'AU05_r', 'AU09_r']
# [284, 'AU01_r', 'AU06_r']
# [285, 'AU01_r', 'AU02_r']
# [286, 'AU01_r', 'AU04_r']
# [287, 'AU05_r']
# [288, 'AU04_r', 'AU45_r']
# [289, 'AU04_r']
# [290, 'AU01_r', 'AU04_r']
# [291, 'AU01_r']
# [292, 'AU01_r', 'AU04_r']
# [293, 'AU05_r', 'AU07_r']
# [294, 'AU01_r', 'AU04_r']
# [295, 'AU05_r']
# [296, 'AU45_r']
# [297, 'AU45_r']
# [298, 'AU04_r']
# [299, 'AU01_r', 'AU05_r']
# [300, 'AU05_r']
# [301, 'AU02_r', 'AU06_r']
# [302, 'AU06_r', 'AU45_r']
# [303, 'AU05_r', 'AU45_r']
# [304, 'AU05_r', 'AU06_r', 'AU07_r']
# [305, 'AU04_r', 'AU07_r']
# [306, 'AU07_r']
# [307, 'AU01_r', 'AU06_r']
# [308, 'AU06_r', 'AU07_r']
# [309, 'AU01_r']
# [310, 'AU07_r']
# [311, 'AU01_r', 'AU04_r']
# [312, 'AU05_r', 'AU45_r']
# [313, 'AU01_r', 'AU04_r']
# [314, 'AU01_r']
# [315, 'AU45_r']
# [316, 'AU01_r']
# [317, 'AU01_r', 'AU05_r']
# [318, 'AU01_r']
# [319, 'AU07_r', 'AU45_r']
# [320, 'AU45_r']
# [321, 'AU07_r', 'AU09_r']
# [322, 'AU04_r', 'AU06_r']
# [323, 'AU04_r', 'AU09_r']
# [324, 'AU04_r', 'AU05_r']
# [325, 'AU05_r']
# [326, 'AU04_r', 'AU07_r']
# [327, 'AU01_r', 'AU45_r']
# [328, 'AU01_r', 'AU04_r']
# [329, 'AU01_r', 'AU04_r', 'AU06_r']
# [330, 'AU07_r']
# [331, 'AU45_r']
# [332, 'AU01_r']
# [333, 'AU04_r']
# [334, 'AU01_r', 'AU04_r']
# [335, 'AU06_r']
# [336, 'AU04_r', 'AU06_r']
# [337, 'AU07_r', 'AU45_r']
# [338, 'AU05_r', 'AU06_r']
# [339, 'AU06_r', 'AU45_r']
# [340, 'AU01_r']
# [341, 'AU07_r', 'AU45_r']
# [342, 'AU04_r']
# [343, 'AU05_r']
# [344, 'AU01_r', 'AU04_r', 'AU05_r']
# [345, 'AU02_r', 'AU45_r']
# [346, 'AU01_r', 'AU09_r']
# [347, 'AU05_r']
# [348, 'AU01_r', 'AU04_r']
# [349, 'AU06_r', 'AU09_r']
# [350, 'AU01_r', 'AU06_r']
# [351, 'AU01_r']
# [352]
# [353, 'AU05_r', 'AU09_r']
# [354, 'AU45_r']
# [355, 'AU09_r', 'AU45_r']
# [356, 'AU01_r']
# [357, 'AU01_r', 'AU45_r']
# [358, 'AU01_r', 'AU05_r']
# [359, 'AU04_r', 'AU07_r']
# [360, 'AU01_r', 'AU45_r']
# [361, 'AU07_r']
# [362, 'AU06_r', 'AU07_r']
# [363, 'AU02_r', 'AU04_r']
# [364, 'AU07_r']
# [365, 'AU07_r', 'AU09_r']
# [366, 'AU01_r', 'AU06_r']
# [367, 'AU04_r', 'AU06_r']
# [368, 'AU01_r', 'AU04_r']
# [369, 'AU01_r', 'AU45_r']
# [370, 'AU04_r', 'AU06_r']
# [371, 'AU01_r']
# [372, 'AU01_r', 'AU05_r']
# [373, 'AU45_r']
# [374, 'AU01_r', 'AU05_r']
# [375, 'AU01_r', 'AU06_r']
# [376, 'AU01_r', 'AU02_r']
# [377, 'AU02_r']
# [378, 'AU04_r', 'AU07_r']
# [379, 'AU01_r', 'AU06_r']
# [380, 'AU02_r', 'AU04_r']
# [381, 'AU05_r', 'AU45_r']
# [382, 'AU04_r', 'AU06_r']
# [383, 'AU04_r', 'AU06_r', 'AU07_r']
# [384, 'AU02_r', 'AU45_r']
# [385, 'AU06_r', 'AU07_r', 'AU09_r']
# [386, 'AU02_r']
# [387, 'AU01_r', 'AU45_r']
# [388, 'AU01_r', 'AU09_r']
# [389, 'AU01_r', 'AU07_r']
# [390, 'AU45_r']
# [391, 'AU01_r', 'AU45_r']
# [392, 'AU05_r']
# [393, 'AU01_r']
# [394, 'AU01_r']
# [395, 'AU02_r', 'AU06_r']
# [396, 'AU02_r', 'AU05_r']
# [397, 'AU04_r']
# [398, 'AU01_r']
# [399, 'AU01_r', 'AU45_r']
# [400, 'AU07_r']
# [401, 'AU06_r']
# [402, 'AU06_r', 'AU07_r', 'AU45_r']
# [403, 'AU01_r', 'AU02_r']
# [404, 'AU05_r']
# [405, 'AU02_r', 'AU05_r']
# [406, 'AU01_r', 'AU05_r', 'AU06_r']
# [407, 'AU05_r', 'AU07_r']
# [408, 'AU04_r']
# [409, 'AU01_r']
# [410, 'AU45_r']

# %%
upper_data, upper_cluster = groupCluster(upper_groupings)
upper_cluster.head()
# Out:
#      N          clusters
# 12  29  [AU01_r, AU04_r]
# 5   19  [AU06_r, AU07_r]
# 20  17  [AU01_r, AU05_r]
# 6   15  [AU04_r, AU06_r]
# 0   14  [AU04_r, AU07_r]

# %% [markdown]
# ## Cluster by lower face AU

# %% [markdown]
# #### Get Grouping Data

# %%
lower_groupings = getGrouping(lower_df)
# Out:
# [0, 'AU14_r', 'AU15_r']
# [1, 'AU15_r', 'AU17_r', 'AU26_r']
# [2, 'AU17_r', 'AU25_r', 'AU26_r']
# [3, 'AU17_r', 'AU26_r']
# [4, 'AU20_r', 'AU25_r']
# [5, 'AU14_r', 'AU17_r']
# [6, 'AU26_r']
# [7, 'AU23_r', 'AU25_r', 'AU26_r']
# [8, 'AU12_r', 'AU25_r']
# [9, 'AU15_r', 'AU26_r']
# [10, 'AU10_r', 'AU17_r']
# [11, 'AU15_r', 'AU20_r']
# [12, 'AU12_r', 'AU17_r', 'AU20_r']
# [13, 'AU25_r', 'AU26_r']
# [14, 'AU14_r', 'AU26_r']
# [15, 'AU10_r', 'AU12_r']
# [16, 'AU10_r', 'AU15_r']
# [17, 'AU17_r', 'AU20_r']
# [18, 'AU25_r']
# [19, 'AU10_r', 'AU15_r', 'AU23_r']
# [20, 'AU20_r']
# [21, 'AU15_r', 'AU25_r']
# [22, 'AU12_r', 'AU14_r', 'AU23_r']
# [23, 'AU10_r', 'AU25_r']
# [24, 'AU26_r']
# [25, 'AU14_r', 'AU17_r']
# [26, 'AU12_r', 'AU14_r', 'AU20_r']
# [27, 'AU17_r']
# [28, 'AU14_r', 'AU23_r']
# [29, 'AU26_r']
# [30, 'AU14_r', 'AU20_r', 'AU25_r']
# [31, 'AU12_r', 'AU25_r', 'AU26_r']
# [32, 'AU20_r']
# [33, 'AU15_r', 'AU26_r']
# [34, 'AU10_r', 'AU17_r']
# [35, 'AU10_r', 'AU25_r']
# [36, 'AU15_r', 'AU20_r']
# [37, 'AU20_r']
# [38, 'AU14_r', 'AU20_r', 'AU25_r']
# [39, 'AU10_r']
# [40, 'AU15_r']
# [41, 'AU10_r', 'AU15_r', 'AU17_r']
# [42, 'AU10_r', 'AU12_r', 'AU20_r']
# [43, 'AU20_r', 'AU23_r', 'AU26_r']
# [44, 'AU14_r', 'AU25_r']
# [45, 'AU10_r', 'AU25_r']
# [46, 'AU15_r', 'AU17_r', 'AU23_r']
# [47, 'AU10_r', 'AU12_r', 'AU17_r']
# [48, 'AU10_r', 'AU17_r', 'AU20_r']
# [49, 'AU10_r']
# [50, 'AU12_r', 'AU25_r']
# [51, 'AU25_r', 'AU26_r']
# [52, 'AU26_r']
# [53, 'AU15_r', 'AU17_r', 'AU23_r']
# [54, 'AU10_r', 'AU23_r', 'AU26_r']
# [55, 'AU10_r', 'AU12_r']
# [56, 'AU10_r', 'AU15_r']
# [57, 'AU12_r', 'AU14_r', 'AU23_r']
# [58, 'AU25_r']
# [59, 'AU10_r', 'AU12_r', 'AU14_r']
# [60, 'AU15_r', 'AU23_r']
# [61, 'AU10_r', 'AU12_r']
# [62, 'AU12_r']
# [63, 'AU25_r', 'AU26_r']
# [64, 'AU12_r', 'AU23_r', 'AU26_r']
# [65, 'AU10_r']
# [66, 'AU17_r']
# [67, 'AU15_r', 'AU26_r']
# [68, 'AU15_r', 'AU20_r']
# [69, 'AU12_r', 'AU25_r']
# [70, 'AU17_r', 'AU23_r']
# [71, 'AU10_r', 'AU12_r', 'AU14_r']
# [72, 'AU15_r', 'AU17_r']
# [73, 'AU10_r', 'AU15_r', 'AU25_r']
# [74, 'AU10_r', 'AU12_r']
# [75, 'AU10_r', 'AU17_r']
# [76, 'AU10_r', 'AU14_r']
# [77, 'AU26_r']
# [78, 'AU10_r', 'AU20_r']
# [79]
# [80, 'AU12_r', 'AU14_r']
# [81, 'AU25_r']
# [82, 'AU17_r', 'AU25_r', 'AU26_r']
# [83, 'AU26_r']
# [84, 'AU26_r']
# [85, 'AU10_r', 'AU15_r']
# [86, 'AU15_r', 'AU17_r']
# [87, 'AU10_r', 'AU20_r']
# [88, 'AU15_r', 'AU20_r']
# [89, 'AU14_r', 'AU26_r']
# [90, 'AU26_r']
# [91, 'AU15_r']
# [92, 'AU15_r']
# [93, 'AU26_r']
# [94, 'AU25_r', 'AU26_r']
# [95, 'AU17_r', 'AU26_r']
# [96, 'AU25_r', 'AU26_r']
# [97, 'AU26_r']
# [98, 'AU20_r']
# [99, 'AU17_r']
# [100, 'AU14_r']
# [101, 'AU10_r', 'AU12_r', 'AU25_r']
# [102, 'AU26_r']
# [103, 'AU15_r', 'AU20_r']
# [104, 'AU10_r']
# [105, 'AU15_r', 'AU17_r', 'AU26_r']
# [106, 'AU10_r', 'AU26_r']
# [107, 'AU25_r', 'AU26_r']
# [108, 'AU17_r', 'AU26_r']
# [109, 'AU10_r', 'AU17_r', 'AU20_r']
# [110, 'AU15_r', 'AU23_r']
# [111, 'AU10_r', 'AU15_r']
# [112, 'AU12_r', 'AU26_r']
# [113, 'AU14_r', 'AU26_r']
# [114, 'AU10_r', 'AU26_r']
# [115, 'AU17_r', 'AU20_r']
# [116, 'AU10_r', 'AU17_r']
# [117, 'AU15_r', 'AU25_r']
# [118, 'AU25_r', 'AU26_r']
# [119, 'AU10_r', 'AU12_r']
# [120, 'AU17_r']
# [121, 'AU15_r', 'AU26_r']
# [122, 'AU20_r']
# [123, 'AU12_r', 'AU17_r']
# [124, 'AU23_r', 'AU26_r']
# [125, 'AU15_r', 'AU26_r']
# [126, 'AU12_r', 'AU15_r', 'AU20_r']
# [127, 'AU15_r', 'AU17_r']
# [128, 'AU12_r', 'AU14_r', 'AU23_r']
# [129, 'AU17_r', 'AU23_r']
# [130, 'AU12_r', 'AU14_r', 'AU17_r']
# [131, 'AU17_r', 'AU25_r']
# [132, 'AU17_r']
# [133, 'AU25_r', 'AU26_r']
# [134, 'AU15_r', 'AU17_r', 'AU20_r']
# [135, 'AU26_r']
# [136, 'AU20_r', 'AU26_r']
# [137, 'AU10_r', 'AU25_r', 'AU26_r']
# [138, 'AU15_r', 'AU25_r']
# [139, 'AU14_r', 'AU20_r']
# [140, 'AU10_r', 'AU12_r', 'AU20_r']
# [141, 'AU15_r', 'AU23_r']
# [142, 'AU15_r', 'AU17_r', 'AU26_r']
# [143, 'AU12_r', 'AU17_r']
# [144, 'AU10_r', 'AU17_r', 'AU26_r']
# [145, 'AU15_r', 'AU26_r']
# [146, 'AU26_r']
# [147, 'AU10_r', 'AU15_r']
# [148, 'AU10_r', 'AU20_r']
# [149, 'AU10_r', 'AU26_r']
# [150, 'AU10_r', 'AU25_r', 'AU26_r']
# [151, 'AU15_r', 'AU20_r']
# [152, 'AU26_r']
# [153, 'AU10_r', 'AU12_r', 'AU14_r']
# [154, 'AU26_r']
# [155, 'AU10_r', 'AU17_r', 'AU26_r']
# [156, 'AU15_r', 'AU25_r']
# [157, 'AU15_r', 'AU17_r', 'AU26_r']
# [158, 'AU14_r', 'AU25_r', 'AU26_r']
# [159, 'AU10_r', 'AU14_r', 'AU17_r']
# [160, 'AU20_r', 'AU23_r']
# [161, 'AU15_r', 'AU26_r']
# [162, 'AU14_r', 'AU25_r', 'AU26_r']
# [163, 'AU15_r']
# [164, 'AU15_r']
# [165, 'AU10_r', 'AU26_r']
# [166, 'AU20_r']
# [167, 'AU12_r', 'AU14_r', 'AU23_r']
# [168, 'AU26_r']
# [169, 'AU26_r']
# [170, 'AU17_r', 'AU26_r']
# [171, 'AU23_r', 'AU26_r']
# [172, 'AU10_r', 'AU15_r']
# [173, 'AU10_r', 'AU12_r', 'AU14_r']
# [174, 'AU17_r', 'AU20_r']
# [175, 'AU14_r', 'AU25_r', 'AU26_r']
# [176, 'AU15_r', 'AU23_r']
# [177, 'AU15_r']
# [178, 'AU25_r']
# [179, 'AU14_r']
# [180, 'AU14_r', 'AU15_r', 'AU25_r']
# [181, 'AU10_r', 'AU26_r']
# [182, 'AU10_r', 'AU20_r']
# [183, 'AU25_r', 'AU26_r']
# [184, 'AU10_r', 'AU17_r', 'AU25_r']
# [185, 'AU10_r', 'AU14_r']
# [186, 'AU26_r']
# [187, 'AU10_r', 'AU15_r', 'AU25_r']
# [188, 'AU25_r', 'AU26_r']
# [189, 'AU14_r', 'AU26_r']
# [190, 'AU14_r', 'AU15_r', 'AU26_r']
# [191, 'AU14_r', 'AU17_r', 'AU23_r']
# [192, 'AU15_r', 'AU26_r']
# [193, 'AU17_r']
# [194]
# [195, 'AU23_r', 'AU26_r']
# [196, 'AU17_r']
# [197, 'AU26_r']
# [198, 'AU23_r']
# [199, 'AU10_r', 'AU15_r']
# [200, 'AU10_r', 'AU17_r']
# [201, 'AU10_r', 'AU25_r']
# [202, 'AU15_r', 'AU17_r']
# [203, 'AU25_r', 'AU26_r']
# [204, 'AU26_r']
# [205, 'AU10_r', 'AU12_r']
# [206, 'AU20_r', 'AU23_r']
# [207, 'AU10_r', 'AU14_r', 'AU15_r']
# [208, 'AU17_r', 'AU26_r']
# [209, 'AU14_r', 'AU15_r', 'AU23_r']
# [210, 'AU20_r', 'AU26_r']
# [211, 'AU15_r']
# [212, 'AU14_r', 'AU20_r', 'AU23_r']
# [213, 'AU17_r']
# [214, 'AU10_r', 'AU26_r']
# [215, 'AU15_r', 'AU26_r']
# [216, 'AU10_r', 'AU12_r']
# [217, 'AU20_r']
# [218, 'AU15_r', 'AU25_r']
# [219, 'AU10_r', 'AU20_r']
# [220, 'AU10_r', 'AU26_r']
# [221, 'AU10_r', 'AU17_r']
# [222, 'AU20_r', 'AU26_r']
# [223, 'AU15_r', 'AU26_r']
# [224, 'AU10_r', 'AU12_r']
# [225, 'AU12_r', 'AU14_r']
# [226, 'AU26_r']
# [227]
# [228, 'AU25_r']
# [229, 'AU10_r', 'AU25_r']
# [230, 'AU15_r', 'AU17_r', 'AU23_r']
# [231, 'AU26_r']
# [232, 'AU15_r']
# [233, 'AU12_r', 'AU26_r']
# [234, 'AU25_r', 'AU26_r']
# [235, 'AU14_r', 'AU17_r', 'AU25_r']
# [236, 'AU10_r', 'AU25_r']
# [237, 'AU10_r', 'AU14_r']
# [238, 'AU15_r']
# [239, 'AU26_r']
# [240, 'AU15_r', 'AU17_r', 'AU23_r']
# [241, 'AU23_r']
# [242, 'AU10_r', 'AU26_r']
# [243, 'AU15_r', 'AU23_r']
# [244, 'AU12_r', 'AU14_r', 'AU25_r']
# [245, 'AU26_r']
# [246, 'AU14_r', 'AU23_r', 'AU26_r']
# [247, 'AU15_r']
# [248, 'AU26_r']
# [249, 'AU14_r', 'AU23_r']
# [250, 'AU15_r', 'AU26_r']
# [251, 'AU15_r']
# [252, 'AU23_r', 'AU25_r', 'AU26_r']
# [253, 'AU15_r', 'AU17_r', 'AU23_r']
# [254, 'AU14_r', 'AU26_r']
# [255, 'AU14_r', 'AU15_r', 'AU23_r']
# [256]
# [257, 'AU17_r', 'AU23_r', 'AU26_r']
# [258, 'AU10_r', 'AU25_r']
# [259, 'AU14_r', 'AU17_r', 'AU23_r']
# [260, 'AU12_r', 'AU15_r', 'AU25_r']
# [261, 'AU10_r', 'AU17_r']
# [262, 'AU23_r']
# [263, 'AU15_r', 'AU20_r']
# [264, 'AU10_r', 'AU12_r', 'AU20_r']
# [265, 'AU10_r', 'AU12_r', 'AU14_r']
# [266, 'AU14_r', 'AU25_r', 'AU26_r']
# [267, 'AU26_r']
# [268, 'AU15_r', 'AU20_r', 'AU26_r']
# [269, 'AU10_r', 'AU15_r']
# [270, 'AU26_r']
# [271, 'AU15_r']
# [272, 'AU25_r', 'AU26_r']
# [273, 'AU26_r']
# [274, 'AU10_r', 'AU14_r']
# [275, 'AU15_r', 'AU26_r']
# [276, 'AU10_r', 'AU17_r']
# [277, 'AU12_r', 'AU15_r', 'AU20_r']
# [278, 'AU10_r', 'AU25_r']
# [279, 'AU15_r', 'AU26_r']
# [280, 'AU14_r', 'AU25_r']
# [281, 'AU12_r', 'AU14_r']
# [282, 'AU26_r']
# [283, 'AU17_r', 'AU20_r', 'AU23_r']
# [284, 'AU14_r', 'AU17_r']
# [285, 'AU10_r', 'AU17_r']
# [286, 'AU20_r', 'AU25_r', 'AU26_r']
# [287, 'AU14_r']
# [288, 'AU15_r', 'AU20_r']
# [289, 'AU14_r']
# [290, 'AU15_r']
# [291, 'AU26_r']
# [292, 'AU12_r', 'AU14_r', 'AU15_r']
# [293, 'AU25_r', 'AU26_r']
# [294, 'AU10_r', 'AU20_r']
# [295, 'AU25_r']
# [296, 'AU14_r', 'AU20_r']
# [297, 'AU20_r']
# [298, 'AU26_r']
# [299, 'AU10_r', 'AU12_r', 'AU25_r']
# [300, 'AU10_r', 'AU20_r']
# [301, 'AU15_r', 'AU20_r']
# [302, 'AU12_r', 'AU23_r']
# [303]
# [304, 'AU10_r', 'AU23_r', 'AU26_r']
# [305, 'AU10_r', 'AU14_r', 'AU26_r']
# [306]
# [307, 'AU17_r', 'AU26_r']
# [308, 'AU10_r', 'AU15_r', 'AU17_r']
# [309, 'AU25_r']
# [310, 'AU10_r', 'AU12_r', 'AU14_r']
# [311, 'AU14_r', 'AU20_r']
# [312, 'AU10_r', 'AU12_r', 'AU25_r']
# [313, 'AU10_r', 'AU23_r']
# [314, 'AU20_r']
# [315, 'AU10_r', 'AU14_r']
# [316, 'AU17_r']
# [317, 'AU14_r', 'AU25_r']
# [318, 'AU17_r']
# [319, 'AU15_r', 'AU25_r']
# [320, 'AU10_r', 'AU17_r', 'AU23_r']
# [321, 'AU23_r', 'AU25_r']
# [322, 'AU15_r']
# [323, 'AU26_r']
# [324, 'AU15_r', 'AU23_r', 'AU26_r']
# [325, 'AU12_r', 'AU17_r']
# [326, 'AU26_r']
# [327, 'AU10_r', 'AU23_r', 'AU26_r']
# [328, 'AU26_r']
# [329, 'AU25_r', 'AU26_r']
# [330, 'AU14_r', 'AU15_r']
# [331, 'AU10_r', 'AU25_r', 'AU26_r']
# [332, 'AU26_r']
# [333, 'AU10_r']
# [334, 'AU10_r', 'AU23_r']
# [335, 'AU26_r']
# [336, 'AU17_r']
# [337, 'AU15_r']
# [338, 'AU15_r', 'AU17_r', 'AU23_r']
# [339, 'AU10_r', 'AU15_r', 'AU23_r']
# [340, 'AU26_r']
# [341, 'AU17_r', 'AU20_r']
# [342, 'AU15_r', 'AU17_r']
# [343, 'AU14_r', 'AU15_r']
# [344, 'AU15_r', 'AU26_r']
# [345, 'AU26_r']
# [346, 'AU15_r', 'AU23_r']
# [347, 'AU26_r']
# [348, 'AU15_r', 'AU20_r']
# [349, 'AU20_r', 'AU25_r']
# [350, 'AU10_r', 'AU17_r']
# [351, 'AU14_r']
# [352, 'AU10_r']
# [353, 'AU20_r', 'AU26_r']
# [354, 'AU10_r']
# [355, 'AU20_r', 'AU25_r']
# [356, 'AU17_r', 'AU25_r']
# [357, 'AU14_r']
# [358, 'AU25_r', 'AU26_r']
# [359, 'AU10_r', 'AU12_r']
# [360]
# [361, 'AU10_r', 'AU14_r']
# [362, 'AU10_r']
# [363, 'AU17_r']
# [364, 'AU10_r', 'AU15_r']
# [365, 'AU10_r', 'AU15_r']
# [366, 'AU10_r']
# [367, 'AU10_r', 'AU17_r', 'AU26_r']
# [368, 'AU17_r', 'AU20_r']
# [369, 'AU10_r', 'AU12_r', 'AU26_r']
# [370, 'AU10_r', 'AU14_r']
# [371, 'AU17_r', 'AU20_r']
# [372, 'AU17_r', 'AU20_r']
# [373, 'AU17_r']
# [374, 'AU10_r', 'AU23_r', 'AU26_r']
# [375, 'AU10_r', 'AU12_r']
# [376, 'AU14_r', 'AU25_r', 'AU26_r']
# [377, 'AU26_r']
# [378, 'AU10_r', 'AU25_r']
# [379, 'AU14_r', 'AU15_r', 'AU23_r']
# [380, 'AU25_r', 'AU26_r']
# [381, 'AU20_r']
# [382, 'AU17_r']
# [383, 'AU10_r', 'AU25_r', 'AU26_r']
# [384, 'AU10_r', 'AU15_r', 'AU17_r']
# [385, 'AU14_r', 'AU20_r', 'AU25_r']
# [386, 'AU10_r', 'AU12_r', 'AU25_r']
# [387, 'AU14_r', 'AU17_r', 'AU23_r']
# [388, 'AU10_r', 'AU20_r']
# [389, 'AU15_r', 'AU17_r', 'AU20_r']
# [390, 'AU12_r', 'AU17_r', 'AU25_r']
# [391, 'AU10_r', 'AU26_r']
# [392, 'AU26_r']
# [393, 'AU15_r']
# [394, 'AU10_r', 'AU20_r']
# [395, 'AU15_r', 'AU17_r']
# [396, 'AU23_r', 'AU26_r']
# [397, 'AU10_r', 'AU17_r']
# [398, 'AU26_r']
# [399, 'AU10_r', 'AU17_r']
# [400, 'AU15_r', 'AU17_r']
# [401, 'AU15_r', 'AU17_r']
# [402, 'AU26_r']
# [403, 'AU10_r', 'AU14_r']
# [404, 'AU23_r', 'AU26_r']
# [405, 'AU12_r', 'AU14_r', 'AU25_r']
# [406, 'AU25_r', 'AU26_r']
# [407, 'AU26_r']
# [408, 'AU25_r', 'AU26_r']
# [409, 'AU26_r']
# [410, 'AU14_r', 'AU15_r']

# %%
lower_data, lower_cluster = groupCluster(lower_groupings)
lower_cluster.head(10)
# Out:
#      N          clusters
# 12  19  [AU25_r, AU26_r]
# 8   14  [AU15_r, AU26_r]
# 9   12  [AU10_r, AU17_r]
# 14  10  [AU10_r, AU12_r]
# 10  10  [AU15_r, AU20_r]
# 15  10  [AU10_r, AU15_r]
# 40   9  [AU10_r, AU20_r]
# 44   9  [AU10_r, AU26_r]
# 20   9  [AU10_r, AU25_r]
# 37   8  [AU15_r, AU17_r]

# %% [markdown]
# ## Cluster both data

# %%
groupings = getGrouping(df)
# Out:
# [0, 'AU06_r', 'AU14_r', 'AU15_r']
# [1, 'AU05_r', 'AU07_r', 'AU09_r', 'AU17_r', 'AU23_r']
# [2, 'AU06_r', 'AU09_r', 'AU10_r', 'AU20_r']
# [3, 'AU06_r', 'AU09_r', 'AU17_r']
# [4, 'AU06_r', 'AU07_r', 'AU25_r']
# [5, 'AU01_r', 'AU02_r', 'AU10_r']
# [6, 'AU02_r', 'AU45_r']
# [7, 'AU04_r', 'AU06_r', 'AU07_r', 'AU12_r', 'AU14_r']
# [8, 'AU04_r', 'AU12_r', 'AU14_r']
# [9, 'AU09_r', 'AU15_r', 'AU26_r']
# [10, 'AU10_r', 'AU14_r', 'AU17_r']
# [11, 'AU01_r', 'AU17_r', 'AU20_r']
# [12, 'AU06_r', 'AU12_r', 'AU14_r', 'AU17_r', 'AU20_r']
# [13, 'AU12_r', 'AU23_r', 'AU25_r', 'AU26_r']
# [14, 'AU02_r', 'AU05_r', 'AU12_r']
# [15, 'AU07_r', 'AU09_r', 'AU12_r']
# [16, 'AU05_r', 'AU07_r', 'AU15_r']
# [17, 'AU01_r', 'AU04_r', 'AU17_r', 'AU20_r']
# [18, 'AU06_r', 'AU10_r', 'AU25_r']
# [19, 'AU01_r', 'AU10_r', 'AU14_r', 'AU15_r', 'AU23_r']
# [20, 'AU04_r', 'AU15_r']
# [21, 'AU05_r', 'AU26_r']
# [22, 'AU06_r', 'AU09_r', 'AU12_r', 'AU14_r', 'AU23_r']
# [23, 'AU06_r', 'AU07_r', 'AU25_r']
# [24, 'AU01_r', 'AU07_r', 'AU26_r']
# [25, 'AU10_r', 'AU12_r', 'AU14_r', 'AU17_r']
# [26, 'AU02_r', 'AU05_r', 'AU15_r', 'AU23_r']
# [27, 'AU15_r', 'AU17_r', 'AU45_r']
# [28, 'AU01_r', 'AU07_r', 'AU10_r', 'AU45_r']
# [29, 'AU01_r', 'AU02_r']
# [30, 'AU06_r', 'AU09_r', 'AU14_r', 'AU20_r', 'AU45_r']
# [31, 'AU06_r', 'AU15_r', 'AU20_r']
# [32, 'AU01_r', 'AU20_r']
# [33, 'AU02_r', 'AU15_r', 'AU26_r']
# [34, 'AU06_r', 'AU10_r', 'AU17_r']
# [35, 'AU04_r', 'AU10_r', 'AU14_r', 'AU25_r']
# [36, 'AU06_r', 'AU07_r', 'AU15_r']
# [37, 'AU01_r', 'AU04_r', 'AU15_r']
# [38, 'AU01_r', 'AU06_r', 'AU07_r', 'AU12_r']
# [39, 'AU09_r', 'AU10_r', 'AU12_r']
# [40, 'AU02_r', 'AU09_r', 'AU15_r']
# [41, 'AU01_r', 'AU02_r', 'AU05_r', 'AU15_r']
# [42, 'AU06_r', 'AU10_r', 'AU12_r', 'AU20_r']
# [43, 'AU05_r', 'AU09_r', 'AU20_r', 'AU23_r', 'AU26_r']
# [44, 'AU01_r', 'AU04_r', 'AU10_r']
# [45, 'AU04_r', 'AU10_r', 'AU25_r']
# [46, 'AU01_r', 'AU04_r', 'AU25_r']
# [47, 'AU01_r', 'AU06_r', 'AU12_r', 'AU17_r', 'AU45_r']
# [48, 'AU05_r', 'AU07_r', 'AU10_r', 'AU17_r']
# [49, 'AU12_r', 'AU45_r']
# [50, 'AU07_r', 'AU10_r', 'AU17_r', 'AU20_r']
# [51, 'AU25_r', 'AU26_r', 'AU45_r']
# [52, 'AU09_r', 'AU25_r', 'AU26_r']
# [53, 'AU09_r', 'AU15_r', 'AU17_r', 'AU23_r', 'AU26_r']
# [54, 'AU02_r', 'AU05_r', 'AU12_r', 'AU15_r', 'AU20_r']
# [55, 'AU01_r', 'AU06_r', 'AU10_r']
# [56, 'AU10_r', 'AU15_r', 'AU26_r']
# [57, 'AU12_r', 'AU14_r', 'AU17_r', 'AU23_r']
# [58, 'AU02_r', 'AU04_r']
# [59, 'AU04_r', 'AU05_r', 'AU06_r', 'AU07_r']
# [60, 'AU07_r', 'AU09_r', 'AU15_r']
# [61, 'AU02_r', 'AU04_r', 'AU06_r', 'AU10_r']
# [62, 'AU04_r', 'AU06_r', 'AU12_r']
# [63, 'AU10_r', 'AU25_r', 'AU26_r']
# [64, 'AU09_r', 'AU12_r', 'AU26_r', 'AU45_r']
# [65, 'AU04_r', 'AU09_r', 'AU10_r']
# [66, 'AU17_r', 'AU25_r', 'AU45_r']
# [67, 'AU15_r', 'AU26_r', 'AU45_r']
# [68, 'AU05_r', 'AU17_r']
# [69, 'AU04_r', 'AU07_r']
# [70, 'AU04_r', 'AU07_r', 'AU14_r', 'AU23_r']
# [71, 'AU01_r', 'AU02_r', 'AU10_r', 'AU12_r', 'AU14_r']
# [72, 'AU06_r', 'AU15_r', 'AU17_r']
# [73, 'AU01_r', 'AU04_r', 'AU06_r', 'AU07_r', 'AU45_r']
# [74, 'AU04_r', 'AU15_r']
# [75, 'AU01_r', 'AU10_r', 'AU17_r']
# [76, 'AU01_r', 'AU02_r', 'AU07_r', 'AU25_r']
# [77, 'AU04_r', 'AU45_r']
# [78, 'AU05_r', 'AU07_r', 'AU10_r', 'AU20_r']
# [79, 'AU26_r', 'AU45_r']
# [80, 'AU12_r', 'AU45_r']
# [81, 'AU09_r', 'AU10_r', 'AU25_r']
# [82, 'AU09_r', 'AU15_r', 'AU17_r', 'AU25_r', 'AU26_r']
# [83, 'AU01_r', 'AU02_r']
# [84, 'AU17_r', 'AU26_r']
# [85, 'AU06_r', 'AU10_r', 'AU15_r', 'AU20_r']
# [86, 'AU09_r', 'AU15_r', 'AU17_r']
# [87, 'AU06_r', 'AU07_r', 'AU09_r', 'AU20_r']
# [88, 'AU07_r', 'AU14_r', 'AU15_r']
# [89, 'AU01_r', 'AU10_r', 'AU14_r']
# [90, 'AU02_r', 'AU45_r']
# [91, 'AU14_r', 'AU15_r']
# [92, 'AU04_r', 'AU15_r', 'AU23_r']
# [93, 'AU26_r']
# [94, 'AU04_r', 'AU17_r', 'AU45_r']
# [95, 'AU02_r', 'AU07_r', 'AU17_r', 'AU26_r']
# [96, 'AU04_r', 'AU25_r', 'AU26_r']
# [97, 'AU01_r', 'AU17_r', 'AU26_r']
# [98, 'AU01_r', 'AU02_r']
# [99, 'AU01_r', 'AU17_r']
# [100, 'AU04_r', 'AU14_r']
# [101, 'AU05_r', 'AU06_r', 'AU10_r', 'AU12_r', 'AU25_r']
# [102, 'AU04_r', 'AU26_r']
# [103, 'AU01_r', 'AU02_r', 'AU05_r', 'AU26_r']
# [104, 'AU01_r', 'AU02_r']
# [105, 'AU01_r', 'AU04_r', 'AU15_r', 'AU17_r', 'AU26_r']
# [106, 'AU06_r', 'AU10_r', 'AU26_r']
# [107, 'AU09_r', 'AU26_r', 'AU45_r']
# [108, 'AU05_r', 'AU06_r', 'AU07_r', 'AU09_r', 'AU17_r']
# [109, 'AU01_r', 'AU02_r', 'AU05_r', 'AU07_r', 'AU12_r']
# [110, 'AU04_r', 'AU06_r', 'AU15_r']
# [111, 'AU06_r', 'AU10_r', 'AU15_r']
# [112, 'AU10_r', 'AU15_r', 'AU45_r']
# [113, 'AU01_r', 'AU04_r', 'AU14_r', 'AU26_r']
# [114, 'AU04_r', 'AU05_r', 'AU10_r', 'AU26_r']
# [115, 'AU04_r', 'AU17_r', 'AU20_r']
# [116, 'AU05_r', 'AU06_r', 'AU07_r']
# [117, 'AU04_r', 'AU07_r', 'AU20_r']
# [118, 'AU04_r', 'AU07_r', 'AU09_r']
# [119, 'AU01_r', 'AU06_r', 'AU14_r', 'AU25_r']
# [120, 'AU02_r', 'AU04_r']
# [121, 'AU01_r', 'AU02_r', 'AU04_r']
# [122, 'AU01_r', 'AU20_r']
# [123, 'AU01_r', 'AU04_r', 'AU20_r']
# [124, 'AU09_r', 'AU10_r', 'AU23_r', 'AU26_r']
# [125, 'AU45_r']
# [126, 'AU04_r', 'AU06_r', 'AU07_r']
# [127, 'AU04_r', 'AU09_r', 'AU15_r']
# [128, 'AU04_r', 'AU07_r', 'AU14_r', 'AU23_r', 'AU45_r']
# [129, 'AU01_r', 'AU02_r', 'AU05_r']
# [130, 'AU05_r', 'AU10_r', 'AU12_r', 'AU14_r', 'AU17_r']
# [131, 'AU01_r', 'AU04_r', 'AU17_r']
# [132, 'AU05_r', 'AU17_r']
# [133, 'AU04_r', 'AU06_r', 'AU07_r', 'AU26_r']
# [134, 'AU04_r', 'AU09_r', 'AU17_r', 'AU20_r']
# [135, 'AU10_r', 'AU25_r', 'AU26_r']
# [136, 'AU02_r', 'AU07_r', 'AU14_r', 'AU45_r']
# [137, 'AU01_r', 'AU04_r', 'AU09_r', 'AU10_r']
# [138, 'AU04_r', 'AU07_r', 'AU25_r']
# [139, 'AU02_r', 'AU25_r']
# [140, 'AU01_r', 'AU02_r', 'AU05_r']
# [141, 'AU04_r', 'AU15_r', 'AU23_r']
# [142, 'AU01_r', 'AU10_r', 'AU15_r', 'AU17_r', 'AU26_r']
# [143, 'AU01_r', 'AU02_r', 'AU17_r']
# [144, 'AU01_r', 'AU02_r', 'AU10_r', 'AU25_r', 'AU26_r']
# [145, 'AU15_r', 'AU20_r', 'AU26_r']
# [146, 'AU26_r']
# [147, 'AU04_r', 'AU07_r', 'AU14_r']
# [148, 'AU04_r', 'AU15_r', 'AU17_r']
# [149, 'AU04_r', 'AU10_r', 'AU26_r']
# [150, 'AU01_r', 'AU05_r', 'AU10_r', 'AU25_r', 'AU26_r']
# [151, 'AU01_r', 'AU02_r']
# [152, 'AU10_r', 'AU26_r']
# [153, 'AU09_r', 'AU10_r', 'AU12_r', 'AU14_r']
# [154, 'AU02_r', 'AU26_r']
# [155, 'AU04_r', 'AU05_r', 'AU12_r', 'AU15_r', 'AU25_r']
# [156, 'AU02_r', 'AU06_r', 'AU15_r']
# [157, 'AU05_r', 'AU06_r', 'AU12_r', 'AU14_r', 'AU25_r']
# [158, 'AU14_r', 'AU25_r', 'AU26_r']
# [159, 'AU10_r', 'AU14_r', 'AU15_r', 'AU17_r']
# [160, 'AU01_r', 'AU04_r', 'AU15_r']
# [161, 'AU01_r', 'AU02_r', 'AU15_r', 'AU45_r']
# [162, 'AU01_r', 'AU02_r', 'AU12_r']
# [163, 'AU01_r', 'AU15_r', 'AU45_r']
# [164, 'AU09_r', 'AU45_r']
# [165, 'AU05_r', 'AU10_r', 'AU26_r']
# [166, 'AU25_r', 'AU45_r']
# [167, 'AU04_r', 'AU05_r', 'AU14_r', 'AU45_r']
# [168, 'AU05_r']
# [169, 'AU01_r', 'AU02_r', 'AU04_r']
# [170, 'AU05_r', 'AU17_r', 'AU23_r', 'AU26_r']
# [171, 'AU15_r', 'AU23_r', 'AU26_r']
# [172, 'AU05_r', 'AU10_r', 'AU15_r', 'AU17_r']
# [173, 'AU05_r', 'AU06_r', 'AU10_r', 'AU12_r', 'AU14_r']
# [174, 'AU04_r', 'AU07_r', 'AU14_r']
# [175, 'AU01_r', 'AU25_r', 'AU26_r', 'AU45_r']
# [176, 'AU04_r', 'AU05_r', 'AU23_r']
# [177, 'AU15_r', 'AU17_r']
# [178, 'AU25_r', 'AU45_r']
# [179, 'AU01_r', 'AU14_r']
# [180, 'AU04_r', 'AU14_r', 'AU15_r', 'AU25_r', 'AU26_r']
# [181, 'AU01_r', 'AU04_r', 'AU15_r', 'AU45_r']
# [182, 'AU05_r', 'AU07_r', 'AU09_r']
# [183, 'AU09_r', 'AU15_r', 'AU20_r', 'AU25_r', 'AU26_r']
# [184, 'AU01_r', 'AU10_r', 'AU12_r', 'AU25_r']
# [185, 'AU01_r', 'AU10_r']
# [186, 'AU10_r', 'AU26_r']
# [187, 'AU05_r', 'AU10_r', 'AU15_r', 'AU25_r']
# [188, 'AU01_r', 'AU25_r', 'AU26_r']
# [189, 'AU05_r', 'AU07_r', 'AU14_r', 'AU26_r']
# [190, 'AU07_r', 'AU12_r', 'AU14_r', 'AU15_r', 'AU26_r']
# [191, 'AU01_r', 'AU02_r', 'AU05_r', 'AU26_r']
# [192, 'AU07_r', 'AU14_r', 'AU15_r', 'AU26_r']
# [193, 'AU17_r', 'AU23_r']
# [194, 'AU26_r']
# [195, 'AU04_r', 'AU09_r', 'AU10_r', 'AU14_r']
# [196, 'AU10_r', 'AU15_r', 'AU17_r']
# [197, 'AU05_r', 'AU26_r']
# [198, 'AU14_r', 'AU15_r', 'AU23_r']
# [199, 'AU04_r', 'AU07_r', 'AU09_r', 'AU15_r']
# [200, 'AU07_r', 'AU10_r', 'AU17_r', 'AU20_r', 'AU45_r']
# [201, 'AU06_r', 'AU10_r', 'AU25_r']
# [202, 'AU15_r', 'AU17_r', 'AU45_r']
# [203, 'AU06_r', 'AU07_r', 'AU26_r']
# [204, 'AU25_r', 'AU26_r']
# [205, 'AU06_r', 'AU07_r', 'AU10_r', 'AU12_r']
# [206, 'AU04_r', 'AU06_r', 'AU10_r']
# [207, 'AU01_r', 'AU04_r', 'AU10_r', 'AU15_r']
# [208, 'AU01_r', 'AU02_r']
# [209, 'AU02_r', 'AU09_r', 'AU15_r', 'AU23_r']
# [210, 'AU04_r', 'AU06_r', 'AU09_r', 'AU12_r', 'AU45_r']
# [211, 'AU15_r', 'AU17_r', 'AU45_r']
# [212, 'AU10_r', 'AU14_r', 'AU15_r', 'AU20_r', 'AU23_r']
# [213, 'AU06_r', 'AU17_r']
# [214, 'AU01_r', 'AU10_r', 'AU26_r']
# [215, 'AU01_r', 'AU02_r', 'AU06_r']
# [216, 'AU04_r', 'AU10_r']
# [217, 'AU04_r', 'AU15_r', 'AU20_r']
# [218, 'AU06_r', 'AU07_r', 'AU25_r']
# [219, 'AU04_r', 'AU07_r', 'AU14_r']
# [220, 'AU04_r', 'AU06_r', 'AU10_r']
# [221, 'AU04_r', 'AU05_r', 'AU10_r']
# [222, 'AU04_r', 'AU06_r', 'AU09_r', 'AU12_r', 'AU45_r']
# [223, 'AU15_r', 'AU17_r', 'AU26_r']
# [224, 'AU04_r', 'AU06_r', 'AU10_r']
# [225, 'AU01_r', 'AU12_r', 'AU14_r']
# [226, 'AU07_r', 'AU15_r', 'AU26_r']
# [227, 'AU05_r']
# [228, 'AU01_r', 'AU05_r']
# [229, 'AU05_r', 'AU10_r', 'AU25_r']
# [230, 'AU05_r', 'AU15_r', 'AU17_r', 'AU23_r', 'AU26_r']
# [231, 'AU26_r']
# [232, 'AU01_r', 'AU15_r', 'AU25_r']
# [233, 'AU07_r', 'AU12_r', 'AU26_r']
# [234, 'AU07_r', 'AU25_r', 'AU26_r']
# [235, 'AU01_r', 'AU02_r', 'AU04_r', 'AU15_r']
# [236, 'AU04_r', 'AU05_r', 'AU25_r']
# [237, 'AU10_r', 'AU14_r', 'AU25_r']
# [238, 'AU15_r']
# [239, 'AU05_r']
# [240, 'AU06_r', 'AU07_r', 'AU09_r', 'AU12_r', 'AU23_r']
# [241, 'AU01_r', 'AU05_r']
# [242, 'AU02_r', 'AU10_r', 'AU26_r']
# [243, 'AU01_r', 'AU05_r', 'AU15_r']
# [244, 'AU12_r', 'AU14_r', 'AU25_r', 'AU45_r']
# [245, 'AU02_r', 'AU26_r']
# [246, 'AU14_r', 'AU20_r', 'AU23_r', 'AU26_r']
# [247, 'AU07_r', 'AU15_r']
# [248, 'AU15_r', 'AU25_r', 'AU26_r']
# [249, 'AU07_r', 'AU14_r', 'AU23_r']
# [250, 'AU04_r', 'AU15_r', 'AU26_r']
# [251, 'AU04_r']
# [252, 'AU09_r', 'AU15_r', 'AU23_r', 'AU25_r', 'AU26_r']
# [253, 'AU05_r', 'AU09_r', 'AU15_r', 'AU17_r', 'AU23_r']
# [254, 'AU14_r', 'AU15_r', 'AU26_r']
# [255, 'AU14_r', 'AU15_r', 'AU23_r', 'AU26_r']
# [256, 'AU26_r']
# [257, 'AU23_r', 'AU26_r', 'AU45_r']
# [258, 'AU01_r', 'AU02_r', 'AU04_r', 'AU45_r']
# [259, 'AU04_r', 'AU14_r', 'AU17_r', 'AU23_r']
# [260, 'AU06_r', 'AU12_r', 'AU15_r', 'AU25_r', 'AU26_r']
# [261, 'AU04_r', 'AU10_r', 'AU17_r']
# [262, 'AU01_r', 'AU05_r']
# [263, 'AU01_r', 'AU05_r', 'AU15_r']
# [264, 'AU06_r', 'AU10_r', 'AU12_r', 'AU20_r']
# [265, 'AU10_r', 'AU12_r', 'AU14_r', 'AU45_r']
# [266, 'AU10_r', 'AU14_r', 'AU17_r', 'AU25_r', 'AU26_r']
# [267, 'AU02_r', 'AU05_r']
# [268, 'AU06_r', 'AU15_r', 'AU20_r', 'AU26_r']
# [269, 'AU01_r', 'AU04_r', 'AU15_r']
# [270, 'AU05_r']
# [271, 'AU04_r', 'AU45_r']
# [272, 'AU06_r', 'AU07_r', 'AU09_r']
# [273, 'AU07_r', 'AU20_r', 'AU45_r']
# [274, 'AU02_r', 'AU04_r', 'AU09_r', 'AU26_r']
# [275, 'AU02_r', 'AU26_r']
# [276, 'AU02_r', 'AU04_r', 'AU17_r', 'AU45_r']
# [277, 'AU06_r', 'AU07_r', 'AU09_r', 'AU20_r']
# [278, 'AU04_r', 'AU06_r', 'AU10_r']
# [279, 'AU01_r', 'AU04_r', 'AU07_r', 'AU12_r']
# [280, 'AU01_r', 'AU02_r', 'AU05_r', 'AU09_r', 'AU14_r']
# [281, 'AU01_r', 'AU06_r', 'AU12_r', 'AU14_r']
# [282, 'AU04_r', 'AU09_r', 'AU26_r']
# [283, 'AU05_r', 'AU09_r', 'AU15_r', 'AU25_r']
# [284, 'AU04_r', 'AU05_r', 'AU14_r', 'AU17_r']
# [285, 'AU01_r', 'AU10_r', 'AU17_r']
# [286, 'AU01_r', 'AU02_r', 'AU04_r', 'AU17_r']
# [287, 'AU14_r', 'AU17_r']
# [288, 'AU04_r', 'AU05_r', 'AU45_r']
# [289, 'AU01_r', 'AU04_r']
# [290, 'AU01_r', 'AU15_r', 'AU17_r']
# [291, 'AU01_r']
# [292, 'AU01_r', 'AU02_r', 'AU04_r']
# [293, 'AU05_r', 'AU07_r', 'AU25_r']
# [294, 'AU01_r', 'AU10_r', 'AU20_r']
# [295, 'AU15_r', 'AU25_r']
# [296, 'AU05_r', 'AU25_r', 'AU45_r']
# [297, 'AU20_r', 'AU45_r']
# [298, 'AU10_r', 'AU26_r']
# [299, 'AU01_r', 'AU05_r', 'AU15_r', 'AU20_r']
# [300, 'AU01_r', 'AU05_r', 'AU10_r']
# [301, 'AU02_r', 'AU15_r', 'AU20_r', 'AU25_r']
# [302, 'AU06_r', 'AU09_r', 'AU12_r']
# [303, 'AU26_r']
# [304, 'AU06_r', 'AU07_r', 'AU12_r', 'AU15_r', 'AU17_r']
# [305, 'AU04_r', 'AU10_r', 'AU14_r', 'AU26_r']
# [306, 'AU07_r']
# [307, 'AU01_r', 'AU06_r', 'AU14_r']
# [308, 'AU06_r', 'AU07_r', 'AU09_r', 'AU17_r', 'AU20_r']
# [309, 'AU01_r', 'AU02_r']
# [310, 'AU06_r', 'AU07_r', 'AU09_r', 'AU10_r']
# [311, 'AU01_r', 'AU14_r', 'AU17_r', 'AU20_r']
# [312, 'AU14_r', 'AU17_r', 'AU26_r', 'AU45_r']
# [313, 'AU09_r', 'AU10_r', 'AU15_r', 'AU23_r']
# [314, 'AU01_r', 'AU20_r']
# [315, 'AU10_r', 'AU14_r', 'AU45_r']
# [316, 'AU01_r', 'AU04_r']
# [317, 'AU01_r', 'AU05_r', 'AU06_r']
# [318, 'AU01_r', 'AU17_r']
# [319, 'AU15_r', 'AU17_r', 'AU45_r']
# [320, 'AU10_r', 'AU14_r', 'AU45_r']
# [321, 'AU23_r', 'AU25_r', 'AU45_r']
# [322, 'AU04_r', 'AU09_r', 'AU15_r']
# [323, 'AU09_r', 'AU26_r']
# [324, 'AU05_r', 'AU15_r', 'AU23_r', 'AU26_r']
# [325, 'AU05_r', 'AU12_r', 'AU17_r']
# [326, 'AU04_r', 'AU07_r', 'AU15_r']
# [327, 'AU10_r', 'AU23_r', 'AU26_r', 'AU45_r']
# [328, 'AU07_r', 'AU17_r', 'AU26_r']
# [329, 'AU04_r', 'AU09_r', 'AU25_r', 'AU26_r']
# [330, 'AU04_r', 'AU07_r', 'AU17_r']
# [331, 'AU07_r', 'AU10_r', 'AU45_r']
# [332, 'AU26_r']
# [333, 'AU04_r', 'AU07_r', 'AU10_r']
# [334, 'AU09_r', 'AU10_r', 'AU15_r', 'AU23_r']
# [335, 'AU15_r', 'AU26_r']
# [336, 'AU06_r', 'AU10_r', 'AU17_r']
# [337, 'AU06_r', 'AU15_r']
# [338, 'AU01_r', 'AU04_r', 'AU05_r', 'AU06_r', 'AU10_r']
# [339, 'AU01_r', 'AU04_r', 'AU10_r', 'AU15_r', 'AU23_r']
# [340, 'AU01_r', 'AU26_r']
# [341, 'AU04_r', 'AU17_r', 'AU20_r']
# [342, 'AU06_r', 'AU15_r', 'AU17_r']
# [343, 'AU05_r', 'AU15_r']
# [344, 'AU04_r', 'AU15_r', 'AU20_r', 'AU26_r']
# [345, 'AU01_r', 'AU02_r', 'AU45_r']
# [346, 'AU06_r', 'AU07_r', 'AU15_r']
# [347, 'AU04_r', 'AU05_r']
# [348, 'AU01_r', 'AU04_r', 'AU20_r', 'AU25_r']
# [349, 'AU14_r', 'AU20_r', 'AU25_r', 'AU45_r']
# [350, 'AU06_r', 'AU10_r', 'AU17_r']
# [351, 'AU01_r', 'AU12_r']
# [352, 'AU10_r']
# [353, 'AU15_r', 'AU20_r', 'AU26_r']
# [354, 'AU10_r', 'AU12_r']
# [355, 'AU20_r', 'AU25_r']
# [356, 'AU01_r', 'AU10_r', 'AU25_r']
# [357, 'AU01_r', 'AU10_r', 'AU12_r']
# [358, 'AU02_r', 'AU25_r', 'AU26_r']
# [359, 'AU04_r', 'AU07_r', 'AU09_r']
# [360, 'AU26_r']
# [361, 'AU07_r', 'AU09_r', 'AU25_r']
# [362, 'AU07_r', 'AU10_r', 'AU12_r']
# [363, 'AU02_r', 'AU17_r']
# [364, 'AU04_r', 'AU10_r', 'AU15_r']
# [365, 'AU04_r', 'AU07_r', 'AU09_r']
# [366, 'AU01_r', 'AU06_r', 'AU10_r']
# [367, 'AU04_r', 'AU06_r', 'AU12_r']
# [368, 'AU07_r', 'AU09_r', 'AU17_r', 'AU20_r']
# [369, 'AU01_r', 'AU12_r', 'AU45_r']
# [370, 'AU04_r', 'AU06_r', 'AU14_r']
# [371, 'AU01_r', 'AU15_r', 'AU20_r']
# [372, 'AU01_r', 'AU05_r', 'AU17_r']
# [373, 'AU15_r', 'AU17_r']
# [374, 'AU01_r', 'AU05_r', 'AU15_r', 'AU17_r']
# [375, 'AU01_r', 'AU06_r', 'AU10_r']
# [376, 'AU01_r', 'AU02_r', 'AU04_r', 'AU10_r', 'AU17_r']
# [377, 'AU01_r', 'AU02_r']
# [378, 'AU04_r', 'AU07_r', 'AU10_r']
# [379, 'AU05_r', 'AU14_r', 'AU15_r', 'AU23_r', 'AU25_r']
# [380, 'AU01_r', 'AU02_r', 'AU04_r']
# [381, 'AU05_r', 'AU15_r', 'AU45_r']
# [382, 'AU04_r', 'AU15_r', 'AU17_r']
# [383, 'AU06_r', 'AU07_r', 'AU09_r', 'AU25_r', 'AU26_r']
# [384, 'AU01_r', 'AU02_r', 'AU14_r', 'AU45_r']
# [385, 'AU01_r', 'AU06_r', 'AU07_r', 'AU09_r', 'AU20_r']
# [386, 'AU01_r', 'AU02_r', 'AU23_r']
# [387, 'AU01_r', 'AU02_r', 'AU04_r', 'AU17_r', 'AU45_r']
# [388, 'AU09_r', 'AU10_r', 'AU20_r']
# [389, 'AU01_r', 'AU07_r', 'AU15_r']
# [390, 'AU01_r', 'AU20_r', 'AU45_r']
# [391, 'AU01_r', 'AU04_r', 'AU45_r']
# [392, 'AU05_r', 'AU07_r']
# [393, 'AU01_r', 'AU04_r']
# [394, 'AU01_r', 'AU10_r', 'AU12_r']
# [395, 'AU02_r', 'AU06_r', 'AU10_r', 'AU15_r']
# [396, 'AU01_r', 'AU02_r', 'AU05_r']
# [397, 'AU04_r', 'AU17_r', 'AU45_r']
# [398, 'AU01_r', 'AU26_r']
# [399, 'AU04_r', 'AU10_r', 'AU45_r']
# [400, 'AU15_r', 'AU17_r', 'AU45_r']
# [401, 'AU06_r', 'AU12_r', 'AU25_r']
# [402, 'AU01_r', 'AU02_r', 'AU26_r']
# [403, 'AU10_r', 'AU14_r', 'AU25_r']
# [404, 'AU02_r', 'AU05_r', 'AU15_r']
# [405, 'AU01_r', 'AU02_r', 'AU05_r', 'AU07_r']
# [406, 'AU01_r', 'AU15_r', 'AU25_r', 'AU26_r']
# [407, 'AU06_r', 'AU25_r', 'AU26_r']
# [408, 'AU04_r', 'AU25_r', 'AU26_r']
# [409, 'AU26_r']
# [410, 'AU14_r', 'AU15_r']

# %%
full_data, cluster = groupCluster(groupings)
cluster.head(10)
# Out:
#      N                  clusters
# 28   8          [AU01_r, AU02_r]
# 26   5  [AU15_r, AU17_r, AU45_r]
# 112  4  [AU01_r, AU02_r, AU04_r]
# 178  4  [AU04_r, AU06_r, AU10_r]
# 54   3  [AU01_r, AU06_r, AU10_r]
# 118  3  [AU01_r, AU02_r, AU05_r]
# 131  3  [AU04_r, AU07_r, AU14_r]
# 135  3          [AU10_r, AU26_r]
# 137  3          [AU02_r, AU26_r]
# 192  3          [AU01_r, AU05_r]

# %% [markdown]
# ### Graphing AU Relationship

# %%
def getRelation(au_data, au_label):
    
    percentage = pd.DataFrame(index = au_label)   
    for au in au_label:
        au_cluster = []
        # for i in lower_au_label:
        for data in au_data:
            if au in data:
                au_cluster.append(data)

        single_au = 0
        other_au = []
        for i in au_cluster:
            if i == [au]:
                single_au += 1
            else:
                for other in i:
                    if other != au:
                        other_au.append(other)

        length = len(other_au) + single_au
        au_percentage = []

        for i in au_label:
            if i == au:
                au_percentage.append(single_au/length)
            else:
                au_percentage.append(other_au.count(i)/length)


        percentage[au] = au_percentage
        percentage.columns.name='main_au'
        percentage.index.name='au_likelihood'
    percentage.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %%
au_label = upper_au.columns.tolist()+lower_au.columns.tolist()

au_data = upper_data
getRelation(upper_data, upper_au.columns.tolist())
getRelation(lower_data, lower_au.columns.tolist())
getRelation(full_data, au_label)

# percentage.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
