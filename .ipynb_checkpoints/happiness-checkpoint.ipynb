# %%
#imports
import pandas as pd     
import matplotlib.pyplot as plt    
# %matplotlib inline
import seaborn as sns    
import numpy as np
from sklearn.mixture import GaussianMixture as GMM
import os
sns.set(style="darkgrid")
from math import pi
from glob import glob
import re
import math
import scipy.interpolate as interp
from tslearn.metrics import dtw, dtw_path
from dtw import dtw,accelerated_dtw
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tslearn/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %% [markdown]
# #### Get Data

# %%
# Reference: https://perials.com/getting-csv-files-directory-subdirectories-using-python/
def getData(PATH, name):
#     PATH = "happinessData/"

    EXT = "*.csv"
    files = [file for path, subdir, files in os.walk(PATH)
                for file in glob(os.path.join(path, EXT))]
    l = []
    for f in files:
        df = pd.read_csv(f)
        result = re.search('/(.*).csv', f)
#         r = re.search('/(.*)',str(result.group(1)))
        video = result.group(1)
        df['video'] = np.full(len(df), video, dtype = int)
        l.append(df)
    df = pd.concat(l, ignore_index=True)
    df['name'] = name
    df = df.rename(columns=lambda x: x.strip())
    return df

# %% [markdown]
# #### Processing Data

# %%
def processData(df):
    df = df[df['success'] != 0]
    df = df[df['confidence'] > 0.80]
    # extracting features
    au = [ 'timestamp','face_id','video', 'gaze_angle_x', 'gaze_angle_y', 'pose_Rx', 'pose_Ry', 'pose_Rz']
    for x in df.columns:
        if '_r' in x and 'AU' in x:
            au.append(x)
    df = df[au]
    return df

# %%
# df = pd.DataFrame()
# df = getData("sadness_csv/", "sadness")
# df = processData(df)

# %%
df.to_csv("sadness/sadness_data.csv")

# %% [markdown]
# #### Normalize Data

# %% [markdown]
# Get Single Person Data - keep the most occuring face_id
# Keep videos with more than 5 and less than 50 frames

# %%
df = pd.read_csv('happiness/happiness_data.csv')
df = df.drop(columns = 'Unnamed: 0')

# %%
videos = set(df['video'])
toRemove = []

for i in videos:
    lst = df[df['video']==i]['video'].tolist()
    if len(lst) <= 5:
        toRemove.append(i)
    df = df.drop(df[(df['video'] == i) & (df['video'] != max(lst,key=lst.count))].index)

for i in toRemove:
    videos.remove(i)
videos = list(videos)
df = df.drop(columns = 'face_id')

# %%
df[df['video'] == videos[10]].head(2)
# Out:
#       timestamp  video  gaze_angle_x  gaze_angle_y  pose_Rx  pose_Ry  pose_Rz  \
# 2877        0.0     34        -0.139         0.412    0.372    0.242   -0.008
# 2878        0.3     34         0.012         0.280    0.195    0.009   -0.039
#
#       AU01_r  AU02_r  AU04_r  ...  AU10_r  AU12_r  AU14_r  AU15_r  AU17_r  \
# 2877    1.18    0.78     0.7  ...    1.26    1.09     0.0    0.06     0.0
# 2878    0.97    0.50     1.5  ...    1.69    0.58     0.2    0.00     0.0
#
#       AU20_r  AU23_r  AU25_r  AU26_r  AU45_r
# 2877     0.0     0.0    1.81    1.95    0.21
# 2878     0.0     0.0    0.83    0.89    0.00
#
# [2 rows x 24 columns]

# %%
len(videos)
# Out:
# 282

# %% [markdown]
# Insert normalized data back to dataframe

# %%
# data = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])

# for i in videos:
#     maximum = max((np.amax(abs(data[df['video']==i]))))
#     data[df['video']==i] = data[df['video']==i].div(maximum)
# lst = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz']
# for i in lst:
#     data[i] = df[i].tolist()

# %%
# df = data.copy()

# %% [markdown]
# ## Clustering Using DTW

# %% [markdown]
# Compute DTW score seperately -> sum up scores

# %%
cluster_data = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
cluster_data.head(2)
# Out:
#    AU01_r  AU02_r  AU04_r  AU05_r  AU06_r  AU07_r  AU09_r  AU10_r  AU12_r  \
# 0    0.58    0.00     0.8    0.00    1.92    0.37    0.91    1.59    2.36
# 1    0.61    0.44     0.0    1.98    1.53    0.00    0.09    1.00    2.01
#
#    AU14_r  AU15_r  AU17_r  AU20_r  AU23_r  AU25_r  AU26_r  AU45_r
# 0    2.98     0.0     0.0     0.0    1.26    2.39    0.89     0.0
# 1    0.94     0.0     0.0     0.0    0.14    1.19    0.95     0.0

# %% [markdown]
# #### Compute DTW based on similarities between each AU features

# %% [markdown]
# I will use normalized AU scoring to identify similar patterns between them. Because I am only looking a signal patterns, I will remove low AU scoring columns to avoid false positive scorings

# %% [markdown]
# ## Cluster Facial AU

# %% [markdown]
# #### Dropping Lower Scoring AU

# %%
def dropLowScoring(vid, df):
    # Getting video
    vid_idx = videos[vid]

    video_df = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
    video_df = video_df[df['video'] == vid_idx]
    
    # Removing videos with the lowest mean
    means = video_df.mean()
    percent20 = max(means)*0.2
    percent40 = max(means)*0.4

    low = video_df.loc[:, video_df.mean() < percent20]
    low = low.loc[:, video_df.max() < percent40]

    video_df = video_df.drop(columns = low.columns)
    return video_df

# %% [markdown]
# #### Get grouping of AU signal (selecting AU with largest value for grouping) using dtw
# eg. select AU6 -> finding AU's with smallest dtw to AU6

# %% [markdown]
# Grouping using DTW scoring (better for busy data)

# %%
from sklearn import preprocessing
def getGroupingDTW(vid, df):

    video_df = dropLowScoring(vid, df)
    
    sim_matrix = pd.DataFrame(index = video_df.columns)
    for key1 in video_df.columns:
        vid1 = []
        for key2 in video_df.columns: 
            a = df[df['video']==videos[vid]][key1]
            b = df[df['video']==videos[vid]][key2]
            a = np.array(a.div(max(a)))
            b = np.array(b.div(max(b)))
            d, cost_matrix, acc_cost_matrix, path = accelerated_dtw(a,b, dist='euclidean')
            vid1.append(d)
        sim_matrix[key1] = vid1.copy()

    
    highest = video_df.loc[:, video_df.max() == max(video_df.max())]
    idx = list(highest.columns)[0]
    grouping = sim_matrix[sim_matrix[idx] < sim_matrix[idx].quantile(0.3)][idx].index.tolist()
    grouping.insert(0,vid)
    print(grouping)
    return grouping

# %% [markdown]
# Grouping using Euklidean scoring (better for simple data)

# %%
from sklearn import preprocessing
def getGroupingAbs(vid, df):

    video_df = dropLowScoring(vid, df)
    
    sim_matrix = pd.DataFrame(index = video_df.columns)
    for key1 in video_df.columns:
        vid1 = []
        for key2 in video_df.columns:
            #normalize data to minimize effect of distancing
            a = df[df['video']==videos[vid]][key1]
            b = df[df['video']==videos[vid]][key2]
            a = np.array(a.div(max(a)))
            b = np.array(b.div(max(b)))
            d = sum(abs(a-b))
            vid1.append(d)
        sim_matrix[key1] = vid1.copy()


    highest = video_df.loc[:, video_df.max() == max(video_df.max())]
    idx = list(highest.columns)[0]
    grouping = sim_matrix[sim_matrix[idx] < sim_matrix[idx].quantile(0.3)][idx].index.tolist()
    grouping.insert(0,vid)
#     print(grouping)
    return grouping

# %% [markdown]
# ### Demonstrate grouping

# %%
# can change the (v) value and run the graphs to 
# see grouping of different clusters

v = 10

# %%
sample = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
sample = sample[df['video']==videos[v]]
sample.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# #### Sample Data containing similar signals after processing

# %%
dropLowScoring(v, df).plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
sample = dropLowScoring(v, df)
col = getGroupingDTW(v, df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title = 'dtw');
col = getGroupingAbs(v, df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title='abs');
# Out:
# [10, 'AU12_r', 'AU25_r', 'AU26_r']

# %% [markdown]
# #### show video

# %%
from IPython.display import Image, display

X = Image(url='Gif/{}.gif'.format(videos[v]))
display(X)
# Out:
# <img src="Gif/34.gif"/>

# %% [markdown]
# ## Grouping

# %% [markdown]
# #### Get AU grouping for entire dataframe

# %%
def getGrouping(df):
    groupings = []
    for i in range(len(videos)):
        group = getGroupingDTW(i, df)
        groupings.append(group.copy())
    return groupings

# %% [markdown]
# #### Group Similar Clusters together -return cluster dataframe

# %%
def groupCluster(groupings):
    data = []
    for i in groupings:
        data.append(i[1:])

    clusters = []
    N = [0]*len(videos)


    for elem in data:
        if len(elem) == 0:
            continue
        if elem not in clusters:
            clusters.append(elem)
        N[clusters.index(elem)] += 1

    N = N[:len(clusters)]

    cluster_df = pd.DataFrame()
    cluster_df['N'] =  N
    cluster_df['clusters'] = clusters
    cluster_df = cluster_df[cluster_df['N'] > 1].sort_values(by=['N'], ascending=False)
    return data, cluster_df

# %% [markdown]
# ## Find grouping for upper face AU

# %%
upper = ['AU01_r','AU02_r','AU04_r','AU05_r','AU06_r','AU07_r','AU09_r', 'AU45_r']
lower = ['AU10_r','AU12_r','AU14_r','AU15_r','AU17_r','AU20_r','AU23_r','AU25_r','AU26_r']
upper_au = df[upper]
lower_au = df[lower]
upper_df = df.drop(columns = lower)
lower_df = df.drop(columns = upper)

# %%
v = 8
sample = upper_au[df['video']==videos[v]]
sample.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %%
sample = dropLowScoring(v, upper_df)
col = getGroupingDTW(v, upper_df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title = 'dtw');
col = getGroupingAbs(v, upper_df)[1:]
sample[col].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5), title='abs');
# Out:
# [8, 'AU04_r', 'AU06_r']

# %% [markdown]
# #### Get Grouping Data

# %% [markdown]
# Note: this may take a little while to run

# %%
upper_groupings
upper_groupings = getGrouping(upper_df)

# %%
upper_data, upper_cluster = groupCluster(upper_groupings)
upper_cluster.head()
# Out:
#      N          clusters
# 1   53          [AU06_r]
# 4   41  [AU06_r, AU07_r]
# 0   30          [AU07_r]
# 20  21  [AU07_r, AU09_r]
# 11  13  [AU06_r, AU09_r]

# %% [markdown]
# ## Cluster by lower face AU

# %% [markdown]
# #### Get Grouping Data

# %%
lower_groupings = getGrouping(lower_df)

# %%
lower_data, lower_cluster = groupCluster(lower_groupings)
lower_cluster.head(5)
# Out:
#      N          clusters
# 3   53  [AU12_r, AU25_r]
# 9   28  [AU10_r, AU12_r]
# 20  27          [AU12_r]
# 5   15  [AU10_r, AU25_r]
# 7   12  [AU12_r, AU14_r]

# %% [markdown]
# ## Cluster both data

# %% [markdown]
# ### Graphing AU Relationship

# %%
lower_au_label = upper_au.columns.tolist()

disgust_percentage = pd.DataFrame(index = lower_au_label)   
for au in lower_au_label:
    au_cluster = []
    # for i in lower_au_label:
    for data in upper_data:
        if au in data:
            au_cluster.append(data)

    single_au = 0
    other_au = []
    for i in au_cluster:
        if i == [au]:
            single_au += 1
        else:
            for other in i:
                if other != au:
                    other_au.append(other)

    length = len(other_au) + single_au
    au_percentage = []

    for i in lower_au_label:
        if i == au:
            au_percentage.append(single_au/length)
        else:
            au_percentage.append(other_au.count(i)/length)

 
    disgust_percentage[au] = au_percentage

# %%
disgust_percentage.columns.name='main_au'
disgust_percentage.index.name='au_likelihood'
disgust_percentage.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %% [markdown]
# ### Find local minima and maxima

# %%
sample = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz']).copy()
sample = sample[df['video'] == videos[0]]
sample.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
test.plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))
test[grouping].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5))

# %%
test
# Out:
#      AU01_r  AU02_r  AU04_r  AU05_r  AU06_r  AU07_r  AU09_r  AU10_r  AU12_r  \
# 776    0.69     0.0    0.19    0.55    1.57    1.95    0.23    1.16    1.91
# 777    0.83     0.0    0.75    0.03    1.59    2.40    0.62    1.24    1.86
# 778    0.76     0.0    0.43    0.11    1.73    2.60    0.25    1.22    1.94
# 779    0.66     0.0    0.40    0.20    1.51    2.26    0.43    0.95    1.84
#
#      AU14_r  AU15_r  AU17_r  AU20_r  AU23_r  AU25_r  AU26_r  AU45_r
# 776    0.50    1.20     0.0     0.0     0.0    1.18    0.36     0.0
# 777    0.39    1.41     0.0     0.0     0.0    1.23    0.60     0.0
# 778    0.25    1.35     0.0     0.0     0.0    1.36    0.95     0.0
# 779    0.05    1.48     0.0     0.0     0.0    1.24    0.72     0.0

# %%
sim_matrix = pd.DataFrame(index = test.columns)
for key1 in test.columns:
    vid1 = []
    for key2 in test.columns:
        #normalize data to minimize effect of distancing
        a = test[key1]
        b = test[key2]
        a = np.array(a.div(max(a)))
        b = np.array(b.div(max(b)))
        d = sum(abs(a-b))
#         d, cost_matrix, acc_cost_matrix, path = accelerated_dtw(a,b, dist='euclidean')


        vid1.append(d)
    sim_matrix[key1] = vid1.copy()

highest = test.loc[:,test.max() == max(test.max())]
idx = list(highest.columns)[0]
grouping = sim_matrix[sim_matrix[idx] < sim_matrix[idx].quantile(0.3)][idx].index.tolist()

# %%
grouping
# Out:
# ['AU06_r', 'AU07_r', 'AU15_r', 'AU25_r']

# %%
test_group = getGroupingDTW(test,)

# %%
a = sample.reset_index
start = sample.index[0]
test = sample.truncate(before=start+9, after=start+12)

# %%
a = np.array(sample['AU07_r'])
local_maxima = np.r_[True, a[1:] > a[:-1]] & np.r_[a[:-1] > a[1:], True]
local_minima = np.r_[True, a[1:] < a[:-1]] & np.r_[a[:-1] < a[1:], True]

print(local_maxima)
print(local_minima)
local_maxima = [i for i, e in enumerate(local_maxima) if e == 1]
local_minima = [i for i, e in enumerate(local_minima) if e == 1]


print(local_maxima)
print(local_minima)
# Out:
# [False  True False False False  True False False  True False False  True
#  False]
# [ True False False  True False False False False False  True False False
#   True]
# [1, 5, 8, 11]
# [0, 3, 9, 12]

# %%
for i,counter in zip(cluster1,range(5)):
    X = Image(url='Gif/{}.gif'.format(videos[i]))
    display(X)
# Out:
# <img src="Gif/17.gif"/>
# <img src="Gif/25.gif"/>
# <img src="Gif/34.gif"/>
# <img src="Gif/50.gif"/>
# <img src="Gif/75.gif"/>

# %% [markdown]
# combine data

# %%
a = [1,1,2,3]
[i for i, e in enumerate(big_data) if e == 1]
# Out:
# [0, 1]

# %%
big_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-c6e70f2c881f> in <module>
# ----> 1 big_data
#
# NameError: name 'big_data' is not defined

# %%
# X = Image(url='Gif/{}.gif'.format(videos[13]))
# display(X)

# X = Image(url='Gif/{}.gif'.format(videos[16]))
# display(X)

# X = Image(url='Gif/{}.gif'.format(videos[20]))
# display(X)

# X = Image(url='Gif/{}.gif'.format(videos[42]))
# display(X)

# X = Image(url='Gif/{}.gif'.format(videos[84]))
# display(X)

# X = Image(url='Gif/{}.gif'.format(videos[147]))
# display(X)
# Out:
# <img src="Gif/36.gif"/>
# <img src="Gif/44.gif"/>
# <img src="Gif/55.gif"/>
# <img src="Gif/110.gif"/>
# <img src="Gif/218.gif"/>
# <img src="Gif/381.gif"/>

# %%
# Out:
# AU20_r     1.0
# AU01_r    15.0
# AU45_r     1.0
# AU12_r    10.0
# AU04_r     3.0
# AU14_r     6.0
# AU17_r     1.0
# AU10_r     6.0
# AU15_r     3.0
# AU05_r     1.0
# AU07_r     6.0
# AU23_r     2.0
# AU25_r     7.0
# AU06_r    15.0
# dtype: float64

# %%
my_set = set.union(*map(set,groupings))
my_set
no_integers = [x for x in my_set if not isinstance(x, int)]
no_integers
# Out:
# ['AU25_r',
#  'AU45_r',
#  'AU10_r',
#  'AU05_r',
#  'AU17_r',
#  'AU20_r',
#  'AU15_r',
#  'AU26_r',
#  'AU01_r',
#  'AU14_r',
#  'AU07_r',
#  'AU02_r',
#  'AU12_r',
#  'AU06_r',
#  'AU23_r',
#  'AU09_r',
#  'AU04_r']

# %%
# for i in range(20,30):
i = 25
print(i)
vid_idx = videos[i]

video_df = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
video_df = video_df[df['video'] == vid_idx]
means = video_df.mean()
percent20 = max(means)*0.2
percent40 = max(means)*0.4

low = video_df.loc[:, test1.mean() < percent20]
low = low.loc[:, test1.max() < percent40]

video_df = video_df.drop(columns = low.columns)
highest = video_df.loc[:, video_df.max() == max(video_df.max())]
print(highest)
# Out:
# 25
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-670-f25089e4e9ce> in <module>
#      14
#      15 video_df = video_df.drop(columns = low.columns)
# ---> 16 highest = video_df.loc[:, video_df.max() == max(video_df.max())]
#      17 print(highest)
#
# ValueError: max() arg is an empty sequence

# %%
for i in groupings:
#     if 'AU06_r' in i:
#         if 'AU09_r' in i:
# #             if 'AU10_r' in i:
# #                 if 'AU12_r' in i:
# #                     print(i)
    print(i)
# Out:
# [0, 'AU06_r', 'AU07_r', 'AU10_r']
# [1, 'AU10_r']
# [2, 'AU06_r', 'AU07_r', 'AU10_r']
# [3, 'AU07_r', 'AU25_r']
# [4, 'AU10_r', 'AU14_r', 'AU15_r', 'AU17_r', 'AU26_r']
# [5, 'AU06_r']
# [6, 'AU06_r']
# [7, 'AU06_r']
# [8, 'AU07_r', 'AU26_r']
# [9, 'AU06_r', 'AU10_r', 'AU12_r']

# %%
# sim_matrix = pd.DataFrame()

# for i in videos:
#     vid1 = []
#     for j in videos:
#         d1 = cluster_data[df['video']==i]
#         d2 = cluster_data[df['video']==j]
#         d, cost_matrix, acc_cost_matrix, path = accelerated_dtw(d1,d2, dist='euclidean')
#         vid1.append(d)
#     print(i)
#     sim_matrix[str(i)] = vid1

# %%
# sim_matrix.to_csv("happinessSim.csv")
sim_matrix = pd.read_csv("happiness_sim.csv")
sim_matrix = sim_matrix.drop(columns = 'Unnamed: 0')

# %%
sim_matrix.head(3)
# Out:
#            4         11         13         17         18         22  \
# 0   0.000000  13.188811  15.612639  20.824972  17.576804  19.272158
# 1  13.188811   0.000000  19.470250  15.978771  14.613659  18.517424
# 2  15.612639  19.470250   0.000000  27.644883  21.859307   8.884757
#
#           23         24         25         28  ...        682        684  \
# 0  14.119607  18.662809  10.965495  18.203356  ...  20.392679  14.704262
# 1  12.413799  22.645750  17.330873  17.927183  ...  25.591417  13.072668
# 2  17.452804  23.295116  17.190978  19.587539  ...   9.544400  21.114742
#
#          685        686        688        689        690        691  \
# 0  44.115031  26.896507  19.037595  16.028686  13.584974  44.583024
# 1  43.792847  25.167757  19.728775  14.492311  14.090859  45.014314
# 2  64.985511  32.729094  21.120308  22.179198  15.255692  56.875799
#
#          692        696
# 0  26.828421  13.396067
# 1  26.109794  15.259656
# 2  36.203157  22.459202
#
# ...

# %% [markdown]
# #### Using UMAP to Cluster and Visualize Data

# %%
import umap
from sklearn.preprocessing import StandardScaler

reducer = umap.UMAP()
embedding = reducer.fit_transform(sim_matrix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-b8bb81748612> in <module>
#       3
#       4 reducer = umap.UMAP()
# ----> 5 embedding = reducer.fit_transform(groupings)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/umap/umap_.py in fit_transform(self, X, y)
#    2010             Embedding of the training data in low-dimensional space.
#    2011         """
# -> 2012         self.fit(X, y)
#    2013         return self.embedding_
#    2014
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/umap/umap_.py in fit(self, X, y)
#    1611         """
#    1612
# ...

# %%
umap_data = pd.DataFrame()
umap_data['x'] = embedding[0:,0]
umap_data['y'] = embedding[0:,1]

# %%
n_components = np.arange(1, 15)
models = [GMM(n, covariance_type='full', random_state=0).fit(umap_data[['x','y']])
for n in n_components]
plt.plot(n_components, [m.bic(umap_data[['x','y']]) for m in models], label='BIC')
plt.show()

# %%
n=8
umap_gmm = GMM(n_components=n, covariance_type='full', random_state=0)
label = umap_gmm.fit(umap_data[['x','y']]).predict(umap_data[['x','y']])
plt.scatter(
    umap_data['x'],
    umap_data['y'],
    c=label,
    cmap='Oranges'
)

# labeling clusters
x = umap_gmm.means_[0:n, 0]
y = umap_gmm.means_[0:n, 1]

for i in range(n):
    plt.annotate(str(i), (x[i], y[i]))

# %%
# for i in range(20):
#     print(len(df[df['video']==(c[6][i])]))

# %% [markdown]
# #### Group Videos According to Cluster

# %%
clusters = pd.DataFrame()

probs = umap_gmm.predict_proba(umap_data)


clusters['videos'] = videos
clusters['labels'] = label
clusters['probs'] = probs.max(1)

# %%
clusters = clusters.sort_values(['probs'], ascending=[False])
clusters
# Out:
#      videos  labels     probs
# 163     414       1  1.000000
# 230     564       1  1.000000
# 10       30       0  1.000000
# 135     345       1  1.000000
# 70      189       0  1.000000
# ..      ...     ...       ...
# 192     489       1  0.564324
# 107     268       0  0.521737
# 125     326       3  0.514059
# 221     546       1  0.505603
# 57      147       7  0.504553
#
# [299 rows x 3 columns]

# %%
c = []
for i in range(n):
    c.append(clusters[clusters['labels'] == i]['videos'].tolist())

# %% [markdown]
# #### Display Clusters

# %% [markdown]
# Cluster 0 -> raise eye brows, mouth open, lower lid crease (pleased smile)
# Cluster 2 -> smiling and talking (saying yes, mouth open, eyes close)
# Cluster 3 -> encouraging/ridiculous smile (brow lower)???
# cluster 5 -> chuckling (mouth open, smiles, lower lid crease)
# cluster 1 and 4, not differentiable without body motion

# %%
from IPython.display import Image, display
from os import path

# num_show = 30
# # for i in [0,2,3,5]:
# i=7
# print("cluster {}".format(i))
# for counter,idx in zip(range(num_show),c[i]):
X = Image(url='Gif/{}.gif'.format(videos[7]))
display(X)

X = Image(url='Gif/{}.gif'.format(videos[10]))
display(X)

X = Image(url='Gif/{}.gif'.format(videos[15]))
display(X)

X = Image(url='Gif/{}.gif'.format(videos[16]))
display(X)

X = Image(url='Gif/{}.gif'.format(videos[18]))
display(X)

X = Image(url='Gif/{}.gif'.format(videos[20]))
display(X)
# if path.isfile('Gif/{}.gif'.format(idx)):
# Out:
# <img src="Gif/24.gif"/>
# <img src="Gif/30.gif"/>
# <img src="Gif/41.gif"/>
# <img src="Gif/44.gif"/>
# <img src="Gif/50.gif"/>
# <img src="Gif/55.gif"/>

# %% [markdown]
# #### cluster time series data

# %%
test = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
interpAuData = interpData(auData,df)

# %%
auData[df['video']==(c[2][0])].describe()
auData = auData.drop(columns = ['AU01_r', 'AU02_r', 'AU05_r', 'AU09_r', 'AU10_r','AU15_r','AU23_r'])

# %%
test[df['video']==(c[3][4])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));
interpAuData[videos.index(c[3][4])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
auData[df['video']==(c[2][0])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
auData[df['video']==(c[2][1])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
# auData[df['video']==(c[3][0])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));
# auData[df['video']==(c[3][1])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));
# auData[df['video']==(c[3][2])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# auData[df['video']==(c[3][3])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));
# auData[df['video']==(c[3][4])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

for i in range(10):
    print(len(auData[df['video']==(c[3][i])]))
# auData = auData.drop(columns = 'AU45_r')
# Out:
# 90
# 97
# 94
# 101
# 257
# 126
# 83
# 68
# 66
# 64

# %%
interpAuData[videos.index(cluster2[0])].describe()
interpAuData[videos.index(cluster2[1])].describe()
interpAuData[videos.index(cluster2[3])].describe()
# Out:
#           AU01_r     AU02_r     AU04_r  AU05_r     AU06_r     AU07_r  \
# count  25.000000  25.000000  25.000000    25.0  25.000000  25.000000
# mean    0.581500   0.084400   1.454400     0.0   0.679867   1.252967
# std     0.259366   0.099984   0.202061     0.0   0.141463   0.322214
# min     0.011667   0.000000   0.916667     0.0   0.493333   0.537500
# 25%     0.430000   0.000000   1.348333     0.0   0.560000   1.096667
# 50%     0.670000   0.046667   1.470000     0.0   0.687500   1.285000
# 75%     0.789167   0.140000   1.580000     0.0   0.764167   1.368333
# max     0.900833   0.318333   1.820000     0.0   1.075833   2.167500
#
#           AU09_r     AU10_r     AU12_r     AU14_r     AU15_r     AU17_r  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    0.568167   1.742167   0.841933   0.930167   0.092900   0.310633
# std     0.114979   0.209622   0.247784   0.434166   0.122051   0.329561
# ...

# %%
interpAuData[videos.index(c[0])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
interpAuData[videos.index(cluster1[1])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
interpAuData[videos.index(cluster1[2])].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# ## Interpolation
# #### Interpolate data into the same dimensions

# %%
def interpData(data, df):
    datas = []
    for i in videos:
        datas.append(data[df['video']==i])

    a = []
    newData = []
    for d in datas:
        temp = pd.DataFrame()
        for key, value in d.iteritems(): 
            a = d[key].tolist()
            length = len(a)
            # interpolate each AU component separately
            inter = interp.interp1d(np.arange(length),list(value))
            reshapedVal = inter(np.linspace(0,len(list(value))-1,10))
            temp[key] = reshapedVal.tolist()
        # put new interpolated data back to dataframe
        newData.append(temp.copy())
    return newData

# %%
allData = df.drop(columns = ['timestamp','video'])
newData = interpData(allData,df)

# %%
import umap
from sklearn.preprocessing import StandardScaler
# initializing data to work with

# normalizing data
reducer = umap.UMAP()
scaled_data = StandardScaler().fit_transform(data)
# reducing data into 2 dimensions
embedding = reducer.fit_transform(scaled_data)
embedding.shape
# Out:
# (16319, 2)

# %%
umap_data = pd.DataFrame()
umap_data['x'] = embedding[0:,0]
umap_data['y'] = embedding[0:,1]

# %%
umap_gmm = GMM(n_components=3, covariance_type='full', random_state=0)
label = umap_gmm.fit(umap_data[['x','y']]).predict(umap_data[['x','y']])
df['label'] = list(label)
plt.scatter(
    umap_data['x'],
    umap_data['y'],
    c=label,
    cmap='Oranges'
)
x = umap_gmm.means_[0:3, 0]
y = umap_gmm.means_[0:3, 1]

for i in range(3):
    plt.annotate(str(i+1), (x[i], y[i]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-325-515ffaccd170> in <module>
#       1 umap_gmm = GMM(n_components=3, covariance_type='full', random_state=0)
#       2 label = umap_gmm.fit(umap_data[['x','y']]).predict(umap_data[['x','y']])
# ----> 3 df['label'] = list(label)
#       4 plt.scatter(
#       5     umap_data['x'],
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# ...

# %% [markdown]
# #### most visible clusters (3, 4, 7, 8, 9)

# %%
lst = []
c3 = []
c4, c7, c8, c9 = [],[],[],[]
for i in videos:
    a = set(df[df['video'] == i]['label'])
#     if len(a) == 1:
    if 3 in a: c3.append(i)
    if 4 in a: c4.append(i)
    if 7 in a: c7.append(i)
    if 8 in a: c8.append(i)
    if 9 in a: c9.append(i)

# %%
print(len(c7))
print(len(c3))
print(len(c4))
print(len(c8))
print(len(c9))
# Out:
# 219
# 162
# 51
# 71
# 45

# %% [markdown]
# ## UMAP Custom

# %% [markdown]
# ## Find Social Signals

# %%
auData = df.drop(columns = ['label','timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
interpAuData = interpData(auData,df)

# %%
interpAuData[c3[0]].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
interpAuData[c3[1]].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
interpAuData[c3[2]].plot().legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# #### Remove lowest AU features

# %%
a = []
for i in c3:
#     a.append(interpAuData[df['video'] == int(i)]['AU06_r'].tolist())
    a.append(interpAuData[df['video'] == int(i)]


print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-247-3aa5ae166f19> in <module>
#       2 for i in c3:
#       3 #     a.append(interpAuData[df['video'] == int(i)]['AU06_r'].tolist())
# ----> 4     a.append(interpAuData[df['video'] == int(i)])
#       5
#       6
#
# TypeError: list indices must be integers or slices, not Series

# %% [markdown]
# ## Kmeans Clustering

# %%
from tslearn.clustering import TimeSeriesKMeans, silhouette_score
from tslearn.utils import to_time_series_dataset

data = df.drop(columns = ['timestamp','video','gaze_angle_x','gaze_angle_y','pose_Rx','pose_Ry','pose_Rz'])
lst = []
plotfeature = pd.DataFrame()
feature = pd.DataFrame(columns = np.arange(25))

for d,i,idx in zip(newData,videos,range(len(videos))):
#     for key, value in d.iteritems(): 
    plotfeature[str(i)] = value.tolist()
    feature.loc[str(i)] = d['AU04_r'].tolist()
X = to_time_series_dataset(feature)

X.shape
# Out:
# (606, 25, 1)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-b59007cee79e> in <module>
# ----> 1 test = to_time_series_dataset([[1],[[1,3],[2,3]],[1,2]])
#       2
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tslearn/utils.py in to_time_series_dataset(dataset, dtype)
#     241     for i in range(n_ts):
#     242         ts = to_time_series(dataset[i], remove_nans=True)
# --> 243         dataset_out[i, :ts.shape[0]] = ts
#     244     return dataset_out.astype(dtype)
#     245
#
# ValueError: could not broadcast input array from shape (2,2) into shape (2,1)

# %%
from tslearn.clustering import TimeSeriesKMeans
km = TimeSeriesKMeans(n_clusters=3, metric="dtw", max_iter=10)
labels = km.fit_predict(X)
centers = km.cluster_centers_
col = feature.columns
np.set_printoptions(precision=2)

# %%
cluster1 = pd.DataFrame(data=km.cluster_centers_[1])
cluster1.plot()

# %%
cluster1 = pd.DataFrame(data=km.cluster_centers_[0])
cluster1
# cluster2 = pd.DataFrame(data=km.cluster_centers_, columns=col)
cluster1.plot(figsize=(10,5), title='Cluster1').legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# cluster2.plot(figsize=(10,5), title = 'Cluster2').legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# #### Map Confusion Matrix values

# %%
from dtw import dtw,accelerated_dtw

data = df.drop(columns = ['video', 'timestamp'])
# l = 10
# m = [[0]*l]*l

# for i in range(10):
#     for j in range(10):
#         d1 = data[df['video'] == videos[i]].interpolate().values
#         d2 = data[df['video'] == videos[j]].interpolate().values
#         d, cost_matrix, acc_cost_matrix, path = accelerated_dtw(d1,d2, dist='euclidean')
#         m[i][j] = d
        
l = []
for j in range(10):
    for i in range(len(videos)):
        d1 = data[df['video'] == videos[j]].interpolate().values
        d2 = data[df['video'] == videos[i]].interpolate().values
        d, cost_matrix, acc_cost_matrix, path = accelerated_dtw(d1,d2, dist='euclidean')
        l.append(d)
    a = pd.DataFrame()
    a[str(j)] = l

# %%
a
# Out:
#                9
# 0       0.000000
# 1      56.257931
# 2      52.178807
# 3      22.923459
# 4      21.292791
# ...          ...
# 1675  454.099296
# 1676   64.149924
# 1677  145.193458
# 1678   64.608194
# 1679   80.827949
#
# [1680 rows x 1 columns]

# %%
# The number of max k value to find the optimal k for k-means clustering.
K_MAX = 15

sse = []

# https://medium.com/analytics-vidhya/how-to-determine-the-optimal-k-for-k-means-708505d204eb
for k in range(1, K_MAX+1):
    kmeans = TimeSeriesKMeans(n_clusters=k, random_state=1).fit(X)
    centroids = kmeans.cluster_centers_
    clusters = kmeans.predict(X)
    print('The shape of the cluster centers for k =', str(k))
    print(kmeans.cluster_centers_.shape)
    curr_sse = 0

    # Calculate square of Euclidean distance of each point from its cluster
    # center and add to current WSS.
    for i in range(len(X)):
      curr_center = centroids[clusters[i]]
      curr_sse += (X[i, 0] - curr_center[0]) ** 2 + \
        (X[i, 1] - curr_center[1]) ** 2
      
    sse.append(curr_sse)

# %%
from tslearn.clustering import TimeSeriesKMeans, silhouette_score
from tslearn.utils import to_time_series_dataset

d1 = pd.DataFrame()
data = []
timestamp = df[['timestamp','video']]
timestamps = []
# for i in videos:
#     timestamps.append(timestamp[timestamp['video'] == i]['timestamp'])
for i in videos: 
    d1 = df[df['video'] == i]
    d1 = d1.drop(columns = ['video']).interpolate().values
    data.append(d1)
X = to_time_series_dataset(data)

from tslearn.clustering import TimeSeriesKMeans
km = TimeSeriesKMeans(n_clusters=2, metric="dtw", random_state = 4)
labels = km.fit_predict(X)
centers = km.cluster_centers_
np.set_printoptions(precision=2)

# %%
# col = df.columns
# col = col.drop('video')

# cluster1 = pd.DataFrame(data=km.cluster_centers_[0], index=range(85), columns=col)
# cluster2 = pd.DataFrame(data=km.cluster_centers_[1], index=range(85), columns=col)

# cluster1.plot(figsize=(10,5), title='Cluster1').legend(loc='center left',bbox_to_anchor=(1.0, 0.5));
# cluster2.plot(figsize=(10,5), title = 'Cluster2').legend(loc='center left',bbox_to_anchor=(1.0, 0.5));

# %%
len(labels)
len(videos)
# Out:
# 169
